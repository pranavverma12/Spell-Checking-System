# %% [markdown]
# # Assignment 1
#
# This assignment will involve the creation of a spellchecking system and an evaluation of its performance. You may use the code snippets provided in Python for completing this or you may use the programming language or environment of your choice
#
# Please start by downloading the corpus `holbrook.txt` from Blackboard
#
# The file consists of lines of text, with one sentence per line. Errors in the line are marked with a `|` as follows
#
#     My siter|sister go|goes to Tonbury .
#
# In this case the word 'siter' was corrected to 'sister' and the word 'go' was corrected to 'goes'.
#
# In some places in the corpus two words maybe corrected to a single word or one word to a multiple words. This is denoted in the data using underscores e.g.,
#
#     My Mum goes out some_times|sometimes .
#
# For the purpose of this assignment you do not need to separate these words, but instead you may treat them like a single token.
#
# *Note: you may use any functions from NLTK to complete the assignment. It should not be necessary to use other libraries and so please consult with us if your solution involves any other external library. If you use any function from NLTK in Task 6 please include a brief description of this function and how it contributes to your solution.*

# %% [markdown]
# ## Task 1 (10 Marks)
#
# Write a parser that can read all the lines of the file `holbrook.txt` and print out for each line the original (misspelled) text, the corrected text and the indexes of any changes. The indexes refers to the index of the words in the sentence. In the example given, there is only an error in the 10th word and so the list of indexes is [9]. It is not necessary to analyze where the error occurs inside the word.
#
# Then split your data into a test set of 100 lines and a training set.

# %%
from google.colab import files
import io
uploaded = files.upload()

#To solve the error "initial_value must be unicode or None, not str" decode is used
lines = io.StringIO(uploaded['holbrook.txt'].decode('utf-8')).readlines()
# Out:
#      <input type="file" id="files-f8a4c51d-504e-49d0-b980-a6894bdd8f7e" name="files[]" multiple disabled />
#      <output id="result-f8a4c51d-504e-49d0-b980-a6894bdd8f7e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving holbrook.txt to holbrook.txt

# %%
lines
# Out:
# [u'1 .\r\n',
#  u'NIGEL THRUSH page 48\r\n',
#  u'I have four in my Family Dad Mum and siter|sister .\r\n',
#  u'My Dad works at Melton .\r\n',
#  u'My siter|sister go|goes to Tonbury .\r\n',
#  u'My Mum goes out some_times|sometimes .\r\n',
#  u'I go to Bridgebrook i go out some_times|sometimes on Tuesday night i go to Youth clob|club .\r\n',
#  u'On thursday nights I go bell_ringing|bellringing on Saturdays I go down to the farm .\r\n',
#  u'on sundays I go to church .\r\n',
#  u'I go to bed at 10 o clock I wakh|watch TV at 5 o clock I live in a house .\r\n',
#  u'The house is in the world .\r\n',
#  u'I live at Boar Parva it is near Melton and Bridgebrook and Smallerden .\r\n',
#  u'The house is white it has stone up the frount|front it is the first from Bridgebrook and the sexeon|second from Smallerden .\r\n',
#  u'My Mum is at home She goes to the shop on fridays My Dad goes to work at Smallerden .\r\n',
#  u'What I do when I get home from school .\r\n',
#  u'On monday I sometimes go down the farm in the night I wach|watch TV there is BBC and I.T.V.\r\n',
#  u'I like I.T.V.\r\n',
#  u'We call Anglia I.T.V.\r\n',
#  u'We have got Anglia like to wach|watch cow_Boys|cowboys .\r\n',
#  u'On Tuesday I get off the bus and some_times|sometimes in the night I go to the Youth colbe|club .\r\n',
#  u'I like to wach|watch T.V.\r\n',
#  u'there is a lot of things on T.V.\r\n',
#  u'I wach|watch it each night .\r\n',
#  u'.\r\n',
#  u'I thing|think tv|TV is good but people say it gives us squar|square iyes|eyes .\r\n',
#  u'The Murder Car .\r\n',
#  u"1 night when it was dark about 12 oclock|o'clock a man was nock|knocked down by a car .\r\n",
#  u"The body was found a|at 7 oclock|o'clock in the morning .\r\n",
#  u'The name of the man who was kild|killed was Jack Robbinson he has black hair brown eyes blue Jacket and blue Jeans .\r\n',
#  u'No one see|saw the car .\r\n',
#  u'there had bean|been a lot of people nock|knocked down by a car so they cald|called it the murder car .\r\n',
#  u'The Police cam|came out to look for the car .\r\n',
#  u'The other cars were black so one of the other people said .\r\n',
#  u'The murder man has a black beard The next day one of the policemen were killd|killed the next day they found the car over the Hill the|there was the man near it he was dead .\r\n',
#  u'I kissed a girl one night Here|Her iyes|eyes were burning blue She said o do you love me Of course of course I do .\r\n',
#  u'Bell Ringing .\r\n',
#  u'When you start Bell Ringing you haveto|have_to ring a bell be_for|before you can do any_thing|anything als|else .\r\n',
#  u'It takes a lot to ring a bell on the rope there is a sally .\r\n',
#  u'ON the bell there is a weel|wheel .\r\n',
#  u'the weel|wheel has the rope on it some sally|sallies are green and the other|others are red white and blue .\r\n',
#  u'When you can ring .\r\n',
#  u'You rings|ring like this .\r\n',
#  u'These are the names of them Plain Hunt , plain Bob , Grandsire Doubles .\r\n',
#  u'Grandsire Triples it takes a long time to ring them .\r\n',
#  u'Me and my dad bike to Melton .\r\n',
#  u'THE SICK SOW OF THE ARMY COURT\r\n',
#  u"One day Sergent S . M . Bullimore told Hut 29 to clean Cynthia|Cynthia's pig sty out .\r\n",
#  u'When Hut 29 got there they had to go and get some gass|gas marsks|masks because the smell was to strong\r\n',
#  u'When S M Bullimore came to the pig sty the pig was laid out on the foor|floor\r\n',
#  u'when they came back S . M . Bullimore said wat|what have you been doing to my sow\r\n',
#  u'we have not done anything we had to go and get some gass|gas marsks|masks because the smell was to|too strong\r\n',
#  u'that is only the soap wat|what I wosh|wash it with\r\n',
#  u'prasp|perhaps he et|ate some soap\r\n',
#  u'Flogger said shall I go and get the vet\r\n',
#  u'get back in the line be_for|before I put you on charge\r\n',
#  u'what did you say\r\n',
#  u'o nothing sir\r\n',
#  u'go and get some wiskey|whiskey\r\n',
#  u'okay sir\r\n',
#  u'put some soap in it Flogger said Oswald\r\n',
#  u'OK said Flogger\r\n',
#  u'Flogger went off\r\n',
#  u'a little while after he came with a large soape|soap wiskey|whiskey\r\n',
#  u'he cave|gave it to S . M . Bullimore\r\n',
#  u'Then he cave|gave it to the pig\r\n',
#  u'A little while after the pig go|got up and there beside here|her were six little pigs\r\n',
#  u'S M Bullimore said that made here|her better that was not me that was the sope|soap\r\n',
#  u'you are on charge\r\n',
#  u'wat|what did you give here|her\r\n',
#  u'I cave|gave her some wiskey|whiskey and sope|soap you cave|gave her that\r\n',
#  u'no I knver|never I sir\r\n',
#  u'you did\r\n',
#  u"thats|that's one thing sir It has made her better .\r\n",
#  u'Pigs When young up to being kild|killed for bacon\r\n',
#  u'When they are young you have to wate|wait 3 days then you can injeck|inject them for pneumonia diseases\r\n',
#  u'you have mack|make shore|sure they have drye|dry straw\r\n',
#  u'when you clean them out you should not leave a falk|fork in with them because the mother might nock|knock it down and the little pigs might stab them_souve|themselves\r\n',
#  u'we give the|them worme|worm pouder|powder\r\n',
#  u'that is when they get the worme|worm\r\n',
#  u'this will stop them from going thin\r\n',
#  u'you should box a little place off so only the little pigs can get in it\r\n',
#  u'that is so they can ge|get out of the way of there|their mother\r\n',
#  u'some people put a light in with theme|them to geep|keep them warm\r\n',
#  u'you have to make shore|sure that mother has a lot of milk .\r\n',
#  u'If she as|has not got a_nougth|enough milk you will have to feed them on a bottle\r\n',
#  u'when they came|can eat a little bit you can get them some little nuts of|for fating|fattening\r\n',
#  u'they can eate|eat some meal when they get a little biger|bigger\r\n',
#  u'we give them some fating|fattening food called Nomber 2\r\n',
#  u'whe|when you wean that is take them from their mother you have got to see if they fight if there is any little wones|ones\r\n',
#  u'fighting\r\n',
#  u'when they and|are bing|big you have to see about waying|weighing\r\n',
#  u'when they have been waid|weighed and reddy|ready to go away to be kild|killed .\r\n',
#  u'Billy Bunter was to|too large So they sent for Im|Him in charge\r\n',
#  u'Im|Him in charge was to|too thin So they sent fro|for Rin Tin Tin\r\n',
#  u'Rin Tin Tin heart is poor So they sent for Barbra Moore\r\n',
#  u'Barbra Moore was having dinner So the|they sent for Yule Brinner\r\n',
#  u'Yule Brinner sang to|too high Then they went to space in the sky\r\n',
#  u'My heart is full of sadness My heart is full of joy It might be my wife Or it might be Helen of Toy|Troy\r\n',
#  u'One Saturday I though|thought I would go to the Races at London\r\n',
#  u'I went on my Royl|Royal Enfield\r\n',
#  u'they can go quite farst|fast\r\n',
#  u'this was a Royl|Royal Enfield Consulatoin|_?_\r\n',
#  u'there were some Royl|Royal Enfield Racing there as well\r\n',
#  u'I saw a Royl|Royal Enfield come first it was like mine .\r\n',
#  u'there were the new Japannese|Japanese Hondor|Honda\r\n',
#  u'they are very farst|fast and geting|getting quite popular in England\r\n',
#  u'I saw one man come off\r\n',
#  u'he was on a B.S.A.\r\n',
#  u'One man had to go in Hospital because he broke is|his lege|leg\r\n',
#  u'a_nouther|another man hearte|hurt is|his arm in a sidecar race\r\n',
#  u"I dont|don't thing|think it was much\r\n",
#  u'I sow|saw a side_car|sidecar turne|turn right over\r\n',
#  u'the side_care|sidecar man was alright but the motor_bike|motorbike Rider was thrown into the crowd\r\n',
#  u"I dont|don't no|know what hapend|happened to him\r\n",
#  u'he was heart|hurt quite bad .\r\n',
#  u'the sidecar broke off the moter_bike|motorbike and spund|spun down the track for 7 yards then hit a man who was on the corner and killed him\r\n',
#  u'his hat was blowing down the track\r\n',
#  u'the moter_bike|motorbike caugh|caught fire and blow|blew up\r\n',
#  u'the petal|petrol went all over the track but they sone|soon put it out by sand\r\n',
#  u'there was some oil got on the track as well\r\n',
#  u'it made it very slippery\r\n',
#  u'They|There were quite a few people there because it was a nice dry day\r\n',
#  u'The fianl|final race was on\r\n',
#  u'there were 2 Royl|Royal Enfield 3 Japanese Hondor|Honda 1 B.S.A.\r\n',
#  u'3 Triumh|Triumph\r\n',
#  u'they were on the starting line\r\n',
#  u"Bang there|they're off\r\n",
#  u'one BSA is still on the starting line the rest are round the bend\r\n',
#  u'I can see one man off\r\n',
#  u'he is on a trumh|Triumph\r\n',
#  u'I think a Japanese Hondor|Honda is in the lead\r\n',
#  u'I think he is go|going to lead\r\n',
#  u"his|he's one|won by 3 yards and a Royl|Royal Enfield 2 and a Hondor|Honda 3 .\r\n",
#  u'The End\r\n',
#  u'we went over the football field it was quite wet and soon made my toes cold .\r\n',
#  u'the grass was quite long now it shon|shone with the dew on it .\r\n',
#  u'a field ploud|ploughed next to it I think it was don|done yesterday .\r\n',
#  u'on the other side was an|a hedge\r\n',
#  u'it had a lot of thorns in it .\r\n',
#  u'they hade|had cleand|cleaned the river and made it very wide fore|for the ducks\r\n',
#  u'there were some potato|potatoes in the water .\r\n',
#  u'there were some brussels men sitting in the parth_way|pathway round a fire\r\n',
#  u'we had to go on to a ploud|ploughed field to get round them this made my shoes hevey|heavy .\r\n',
#  u'this was quite muddy\r\n',
#  u'some boys did not think much to it nor did I but we still went .\r\n',
#  u'the dew on the brussels leaves made them look|like pirls|pearls .\r\n',
#  u'Mr . Holbrook went over the brook first\r\n',
#  u'some were boys going round but only one went\r\n',
#  u'after all the rest went over the tree Gerald nealy|nearly went in\r\n',
#  u'one foot toch|touched the water\r\n',
#  u'then we went across the new pice|piece of grass into school\r\n',
#  u'we went and cleand|cleaned our shoes with paper\r\n',
#  u'then the bell went for brack|break .\r\n',
#  u'2 .\r\n',
#  u'JOAN STALL page 54\r\n',
#  u'A poem A little yellow bird sat on my window sill He hop|hopped\r\n',
#  u'and poped|popped about He wisheld|whistled he cherped|chirped .\r\n',
#  u'I trid|tried to chach|catch my little yellow brid|bird but he flew in to the golden yellow sun , O how I wish that was my yellow brid|bird .\r\n',
#  u"ANN That's what you think JOHN That's what I no|know . JEAN the longer you stay here talking we carn't|can't get on with you here DENNIS Come on John I no|know when were|we're\r\n",
#  u"not whanted|wanted JEAN Yes your|you're\r\n",
#  u'not whated|wanted here JOHN Good_by|Goodbye\r\n',
#  u'ANN I knew that would happen .\r\n',
#  u'Apple red and green start are bright The apple trees are tall The leavs|leaves are small The apple|apples\r\n',
#  u'fall in Aount|autumn time\r\n',
#  u'When yow|you get to the corres|cores inside the corres|cores are pips yow|you thorght|throw the corres|cores on the fire to brun|burn then .\r\n',
#  u'the boys in our village go in the orcher|orchard and clim|climb the trees and pinch then|them\r\n',
#  u'all then they run away with then|them .\r\n',
#  u'then the eyewigs|earwigs fall out in there|their pocket|pockets\r\n',
#  u'the apple|apples are sweet .\r\n',
#  u'the trees are fall|full of apple|apples .\r\n',
#  u'some of then|them are cookers .\r\n',
#  u'the apples are so gay haing|hanging on the trees .\r\n',
#  u'with the sun on then|them .\r\n',
#  u'no wonder the boys like pinch then|them\r\n',
#  u'What I am going to do when I leave school\r\n',
#  u'When I leave I whant|want to be a hair_dreser|hairdresser in Melton or Tonbury .\r\n',
#  u'or I whant|want to work in a shop .\r\n',
#  u'I do not whont|want to get marryid|married till I am twentone|twenty_one .\r\n',
#  u'When I have children I am going to leave work and the husbon|husband has got to like children and tack|take them out .\r\n',
#  u'I whant|want twins .\r\n',
#  u'and I whant|want four bridesmaids .\r\n',
#  u'I whont|want to live in a bungalow .\r\n',
#  u'for my holiday I would like to go to butlins|Butlins , for a hunemoon|honeymoon I like to go to Scotland .\r\n',
#  u'On our table there is a sculptor|sculpture modal|model this was made by Mrs Chalmers This is Just like a real think|thing .\r\n',
#  u'this is a modal|model of a boy it is staning|standing on a block wood This was malod|modelled in clay not a whole molad|model Just the Head .\r\n',
#  u'Swan upping\r\n',
#  u'When they do this kind of think|thing they need comer|calmer waters .\r\n',
#  u"they have to handle them very caresll|carefully They use small Boats peolpe|people think this is very corller|cruel to cash|catch them and put stamp on there|their wings , in this picture there is a man carring|carrying on|one out of the Boat its Wing|Wings are tied so that it can not brick|break the mans|man's arms , the swan|swans are dellitent|delicate think|things\r\n",
#  u'Pome|Poem\r\n',
#  u'one day the sun was out and up the stairs I went .\r\n',
#  u'My mother in a temper , I spent my day in bed .\r\n',
#  u"for fear of my mother I darnt|daren't go near .\r\n",
#  u"For fear I dident|didn't get to see the sun ,\r\n",
#  u'There she lays So quitely|quietly there Waiting for the day People weeping waiting Sighing all the days There|Their hearts are weeping Crying so Hearts beting|beating so raperly|rapidly\r\n',
#  u'MARRY|MARY Linda stop it and come out hear|here at once .\r\n',
#  u"JOHN What|What's wong|wrong .\r\n",
#  u'MARRY|MARY I told her that you were thaing|taking me owt|out at half past 12 to_night|tonight JOHN You what .\r\n',
#  u"MARRY|MARY Well I had to tell her JOHN Yes I suppose you did well it|it's not her falt|fault .\r\n",
#  u"its|it's my falt|fault for traing|trying to be a pig .\r\n",
#  u"MARRY|MARY mine too , still you|you've got the job of ching|choosing her or me , JOHN I think I had bet|better go home and think it out LINDA theres|there's nothing to think out I am through with you for good .\r\n",
#  u"JOHN Linda wait LINDA What|What's the good of waiting for you is it .\r\n",
#  u'Linda slander|slammed the door in his face .\r\n',
#  u"JOHN hello Jean carnt|can't we tallk|talk it over and come to some disson|decision\r\n",
#  u'JEAN Talk about what for instead|instance\r\n',
#  u'JOHN Well make it up .\r\n',
#  u"JEAN I am sorry John . theres|there's nothing to make up .\r\n",
#  u"JOHN What do you mean ; There|There's on|no one eles|else us is there .\r\n",
#  u"JEAN Well what if there us|is its|it's got nothing to do with you\r\n",
#  u'JOHN look I am only trining|trying to be nice\r\n',
#  u'JEAN if you lay a hand on me I will scem|scream\r\n',
#  u'JOHN do you think that scards|scares me\r\n',
#  u'yow|you just whant|want to hert|hurt me\r\n',
#  u'JEAN Well perhaps yow|you better not see me eney|any more\r\n',
#  u"JOHN Don't be silly I want to see yow|you to_night|tonight\r\n",
#  u"JOHN I see yow|you at 6 o_,_clock|o'clock\r\n",
#  u"JEAN well all right then JOHN Your|You're a doll\r\n",
#  u"JEAN I dont|don't no|know about that\r\n",
#  u'JOHN Well I do\r\n',
#  u'JEAN goodby|goodbye see you to_night|tonight\r\n',
#  u'charickter|character\r\n',
#  u'There|Their parents David and Jill\r\n',
#  u'It all started with a row with there|their parents ,\r\n',
#  u'JILL I am fed up with yow|you telling me how|who to go out with I am not a two year old I can make up my own mind without arsking|asking you what to do\r\n',
#  u"PARENTS that will be enough from yow|you my girl or els|else your|you'll find your_self|yourself in bed , I just had engouh|enough of you my girl ,\r\n",
#  u'JILL Well I am going to pack my bag and move out .\r\n',
#  u"PARENTS If you move out your|you'll never come in this house again .\r\n",
#  u"JILL Well thats|that's good engouh|enough for me , I|I'll be out in an hour .\r\n",
#  u'PARENTS When you get out you can stay out\r\n',
#  u"JILL thats|that's good .\r\n",
#  u'Jill ran up_stairs|upstairs to pack a case she came down , put on her coat and went out of the front door .\r\n',
#  u"PARENTS She|She's not coming back in this house what_ever|whatever happends|happens .\r\n",
#  u"Jill went to her boyfrends|boyfriend's house , she rang the door bell David opend|opened the door .\r\n",
#  u'DAVID What are you doing hear|here ? I was just coming round to your house to see if you could put me up for the night , I have had a row with my parents .\r\n',
#  u'They told me to get out .\r\n',
#  u'JILL Show|So has|have my parents .\r\n',
#  u"DAVID Lets|Let's go and get married , thats|that's if you whont|want to married .\r\n",
#  u'JILL Of course I do .\r\n',
#  u"DAVID Well lets|let's go and get married then we can get a flat or somethink|something Well they got married and got a house .\r\n",
#  u'They live happly|happily ever after .\r\n',
#  u'The End .\r\n',
#  u'5 , Elmden Road Nr Melton 21 November Dear France , I thought I had better write to you telling yow|you what we do in English with Mr .\r\n',
#  u'Holbrook , well we do a lot of writing such as story and letter , so that it helps when we leave school .\r\n',
#  u'It helps speak properly when we leave school .\r\n',
#  u'Love Joan .\r\n',
#  u'3 .\r\n',
#  u'GEORGE GREEN page 62\r\n',
#  u'A stors|story The BlinD Date People\r\n',
#  u'Rex harrison work|works at visor television factoy|factory Jean smith also wors|works at nsor|_?_ Audrey watston|Watson wonrs|works at the gnenhouen|greenhouse in Melton .\r\n',
#  u'Jean said to Audrey has a sweet and Audrey said to Jean we are This Rex is is exited|excited and Jean and Rex wetn|went two|to the house of He|His mouthr|mother and Rex said to Jean is it my house and Jean sald|said to Rex it is a nis|_?_\r\n',
#  u'The sneking|sneaking gang are dangerous and a tedeboy|teddy_boy went in the shop and the sneking|sneaking gang went two|to the shop wated|waited for the tedeboy|teddy_boy and the tedeboy|teddy_boy kom|came out of the shop and hit a old man out_sild|outside of the shop and the sneking|sneaking gang got the Tedeboy|Teddy_boy and three of sneaking gang the tedeboy|teddy_boy .\r\n',
#  u'The Sick Sow .\r\n',
#  u"Won|One day The Sow was sick and the old frm|farmer went four|for the vethn|vet and the old sow whdn't|wasn't not hethy|healthy an|and fanit|fit and the old frm|farmer sidn|said to vethn|vet the old sow is on_hethy|unhealthy so the vethu|vet sidn|said to the frmh|farmer I will kumh|come and see .\r\n",
#  u'the lod|old sick sow sidn|said the vethn|vet and the frmh|farmer went two|to see the lod|old sick sow and the vethn|vet and the frmh|farmer see lod|old fat sick sow sidn|said the frmh|farmer and went at the frm|farm and not the frmh|farmer ouht|out the big fat sick sow went and ladh|laid down the frmh|farmer went two|too with the big fat sick sow and saw behism|behind and the frmh|farmer .\r\n',
#  u"went in he|his house and he sat down and he bav|_?_ he and sick sow went to|two ladh|lay down and the vetin|vet went and the vent|vet see wat|what is ron|wrong wis|with and the sick sow went to seph|sleep and the vethn|vet went two|to the frmh|farmer's house and sick sow the vethn|vet to the framh|farmer and the vethn|vet sidn|said two|to the old big fat sick sow is a_seph|asleep and the sick sow not the vethn|vet and frmh|farmer run and run up sechrus|_?_ and the sick sow went to the pigs|pigs' house and ladh|laid down and went seph|sleep and the frmh|farmer hot vethn|vet and went bakh|back to Melton and frmh|farmer weth|went to see see sick sow and he ruth|_?_ humit|_?_ and sick old sow wok|woke up and old sow is beththe|better And|End\r\n",
#  u'FOOL : I pray , forbear , my children small For as I am lost as parent to you all , O let me live a while your sport for to advance That I may rise again and with you have a dance .\r\n',
#  u'They sing Now , old father , that you know our will That for your estate we do your body kill Soon after death the bell for your|you shall toll , And wish the Lord he may receive your soul THEN the fool falls down , and the dancers with their swords in their hand|hands , sings|sing the following song .\r\n',
#  u'Good people all you see what we have don|done We have cut down ous|our father like ge|the evening son|sun Ane|And here he lies all in his purple gore And we are afraid he never will dance more\r\n',
#  u'NOVEMBER 11 1960 The sneaking went to the Pub and a pint of brown and went out of the Pub and went round the corner to the shop and see Teddoy|Teddy_boy starte|start troefle|trouble and the sneaking went the teddoy|teddy_boy and the Teddoy|Teddy_boy running up and down the streets and the sneaking went rownd|round the corner to see the Teddoy|Teddy_boy on the .\r\n',
#  u"15 NOVEMBER 1960 The Redex Jack O'Malley : Boss George Green 2 Head John Young 2 head went two|to the pictyres|pictures and hit the maneger|manager and he went down the stars|stairs and hit a women|woman and he|she fainted We home .\r\n",
#  u'The end of the story .\r\n',
#  u'15 NOVEMBER THE POEM OF THE OLD women\r\n',
#  u'My old man a he Old women Hurbured|_?_ she\r\n',
#  u'29 NOVEMBER 1960\r\n',
#  u'I am a man 6 ft tall he laded|landed in the kitching|kitchen ft in the hall\r\n',
#  u'The School .\r\n',
#  u'The school in the meadoy|meadow a school the road a man the cornfield|confide where daffodill|daffodils do grow .\r\n',
#  u'The House of Love The man is a policeman and he to the house of house love and he went in a man crowsed|_?_ the hed|head and the policeman went down on the floor and house of love wos|was haunted and the police went to the haunted house of love and police got the man in house of love the end\r\n',
#  u'The teddyboys|teddy_boys are a Big_haded|big-headed and Police wat|want to get a grip of the Taddyboys|Teddy_boys and see a_Bat|about the kniffe|knife of the shap|shop at the kiffe|cafe and two|to see the shop keeper and to tell the shop keeper not two|to not to give the teddyboys|teddy_boys kiffe|knife .\r\n',
#  u'They are two|too dangers|dangerous and the|they murdered and we are try|trying to stop .\r\n',
#  u'Apple , Apple , on the tree Can you come and please me ? If you can you will be The sweetest apple on the tree .\r\n',
#  u'The stolen Goods On Saturday Tom took a lorry up to London and the Police Star|car stopped Tom and a arrested Him and they took him to the Police Station and question|questioned Him and he went to prison for 7 years\r\n',
#  u'THE ANd|End\r\n',
#  u'The MAN ded|died On Monday a old man went to the old club and not man went see hm|him shot his_self|himself\r\n',
#  u'THE ANd|End\r\n',
#  u'The ship Tony went on the queen Mary on him met James and Phil and I went to see the Q liner\r\n',
#  u'13 JANUARY The hio|story The Thieves At Monday I went to the Car Park and see a man still|steal a car and went to fetch the cops and the caps|cops went to the Car Park and the man went out of the Car Park an|and the caps|cops went to the cops station and I went London I see went up the pipe and went to the pipe and shook the pipe and the man kum|came down the cops come to the man and arrested\r\n',
#  u'The And|End\r\n',
#  u'13 JANUARY The shio|story of the Jap Case On Monday I see Jap case taking bike and went to the shop and taking a bowl swet|sweets went on bike and the police wos|was waten|waiting for Jap Case and Jon case was arrested and the case on Friday and Jap Case was guilt|guilty of taking a bike and He 7 Jail\r\n',
#  u'THE ANd|End\r\n',
#  u'The down gang Saturday the down gang went to the cafe and hit the old man and the cafe man went to ring the polic|police and the polic|police cam|came to the cafe and the down gang beat the polic|police and the down gang run for it a police car caught and the down gang got 7 years in jail and he wife wen|went to se|see She|her husband in Jail and warder in jail house wen|went to he husband and told she|it is tim|time you went said the warder and she went home and he did not coum|come home .\r\n',
#  u'The And|End .\r\n',
#  u'THE Murder hunt In the day man and a girl went in two|to a cafe and man and girl never come out of the cafe and the old mae|man and girl went to a walk and the old man murder and he went home and mother father went two|to the police and the Pollce|Police went in the cafe and the police said to the man at the counter ded|did you serve girl and lod|old man yes the man at the counter thank and the police went four|for walk and the police found the girl murbur|murdered murber|murder hunt the found the mat died\r\n',
#  u'The And|End\r\n',
#  u'25 JANUARY The shio|story trmp|tramps I went to work and I see a trmp|tramp Walking up the rod|road and I went to see the trmp|tramp and I said to the trmp|tramp wat|what do you woth|want I sald|said the old trmp|tramp The rotter school teacher name is Mr . HoLBook he is a tramp he needs a wash and a haircut and a new shirt and he has a big head and beady eyey|eyes I went up heath and I see a old man with a gun and I run down the hill and old man chase you and the|he is gaining my and I fellowed|followed and I was on the side the road and sid|said to an Irish stop the man from shooting you and the Irish hit him knocked him out and went hom|home and sat down Bill sid|said to man do you want a fag and sid|said yes went out\r\n',
#  u'The And|End\r\n',
#  u'In 19 January 29 a murder on the A 10 a young boy in the road coppers went along the road and see the young boy in road and the coppers identify the boy he was John Easter the sergeant\r\n',
#  u'30 MAY 1961 THE GiRL is lockEd|locked in An Attic The missing girl was found in a attic the Lady went down the rad|road got to manh|man and she rung the police station and the fire brigade and the fire manh|man smashed a window and the girl is safe and the mand|man who might able to help them he|his name is John Smith sandy hair and he is driving a stardnd|standard tan|ten XTV 212 If anybody see it please ring Scotland Ysid|Yard Whitehall 1212\r\n',
#  u'The And|End\r\n',
#  u"Toms|Tom's rotten house Tom Sullivans house sticks|stinks and his chairs have holes in them his morther|mother is a fat pig his dad is tashie|trashy and Tom Sullivan wears baggy trousers like old somerset people .\r\n",
#  u'I see a hare running down the fed|field and I see a fsh|fish sticklebacks in the down in the water and a wild rose in the hedge and rook up in the hare|air I see a waterrat|water-rat it went in a hole in the bank .\r\n',
#  u'And I see a dead rook and we climbed over a willow tree and walk down the fed|field and walk back two|to the shool|school .\r\n',
#  u'Hare hare com|come to me or else I kick up a tree fish sticklebacks in the see|sea I will sticklebacks out of the see|sea or you can pull me in the see|sea and I swam in the see|sea .\r\n',
#  u'A rook has a long beak and a big head and long wings and big fet|feet and the colour is black and in the sun is it blue .\r\n',
#  u'The of old man I come out of the old man house and run down the road two|to the telephone ring John and Paulkey|Porky and James and I went up the road two|to the old man house and Paulkey and John and James and John has a gun and we threaten and the old man is bleeding John went to get a doctor and the|he went ring the hospital and the amblance|ambulance come and the old man went tow|to hospital and the gang went two|to see the old man he is dieing|dying and The boy went homse|home and the old man died\r\n',
#  u'A cat run two|to the boor|door and sat on the mat a dog see the cat and cat see the dog and cat ran qu|to the molh|wall and he the rhfn|roof of a house and down cimbenr|chimney and out of the fiar|fire and old man jumth|jumped out of he|his sat|seat and the cat ran ove|over the mat and dog run ou|out two|to the door the cat run up the wah|wall two|to he|the house ran in the and and sat on the mat .\r\n',
#  u'the cat sat on the mat .\r\n',
#  u"A boy of 18 wens|went in the hrmehr|army and denat|didn't lichr|like the hrmehn|army and went on lefnr|leave and he dednt|didn't not comr|come back|douche and 14 day went bihr|by the cpn|captain sedn|said to James Carr has not come doc|back yeth|yet go the he dus|down unz|_?_ sun rod|road Londod|London .\r\n",
#  u'The Gate house Melton\r\n',
#  u'Dear Mr . T. ,\r\n',
#  u'Mr holbrook is a better teacher than you thank|think and I tink|think your Idea is stupid and I do not like your ida|idea yourns|yours sincerely George Green\r\n',
#  u'two clowns in a sercus|circus ring playing a_round|around with a old cat some drunk water hoses pooting|pointing it over each other the crowd laughing at them A saw mill with cows in the back medow|meadow A police car coming along the raod|road with its satren|siren going and men hemmsering|hammering meny|many metet|metals ot|or tin A band playing in a dane|dance hall and yung|young peope|peep pncing|dancing to it It sounds like anetes|_?_ gnt|got killed\r\n',
#  u'4 .\r\n',
#  u'JOHN YOUNG page 77\r\n',
#  u'my family\r\n',
#  u"They|There are 6 of us my dads|dad's the oldest my mums|mum's the second oldest .\r\n",
#  u'my oldest sister is 22 and marrede|married with 1 child of 3 month|months .\r\n',
#  u'I live at Elmden on a farm ... As I am the youngest peason|person in the family I get picted|picked on for a lot of things here is a E.G.\r\n',
#  u'when we are all watching T.V.\r\n',
#  u'dad sais|says make a cup of tea mum .\r\n',
#  u'mum seis|says Doris you make a cup of tea .\r\n',
#  u'Doris sais|says peggy you make a cup of tea peggy sais|says sylver|Sylvia you make it .\r\n',
#  u'Sylver|Sylvia sais|says John you make it .\r\n',
#  u'So as I am the youngest and have now_one|no_one younger to pick on so I have to make the tea .\r\n',
#  u'macwillaims|Macwilliams ran to a brick wall he began to climb it when he got to the top of the guard room then he heard the other guard coming he pull|pulled a knife out of his pocket witch|which he stole from the kichen|kitchen he frow|threw it at the guard it dug into his arm and he but he was still strong he pulled out his truncheon and hit macwillaims|Macwilliams in the face he fell forword|forward off the roof he fell to the ground head first he hit the ground with an almity|almighty thud he broke his head and diad|died\r\n',
#  u'The Jordan family were once a happy crowd .\r\n',
#  u'The family of six lifd|lived in a counsel|council house Just out_side|outside Londen|London But something whenet|went wrong .\r\n',
#  u'Mother and father were always shouting at each other the people across the street could hear them figthing|fighting the children would cry Tommy was the oldest he was 12 he was more groon|grown up that than the others .\r\n',
#  u'Jane was 8 she was frightened of her mum and dad Jone|Joan was 5 and Alan 1 1 / 2 years .\r\n',
#  u'He was to|too young to to understand he was crying all the time never_the_less|nevertheless .\r\n',
#  u'It happened to me When I was 4 years old I very nearly diad|died .\r\n',
#  u'It was one sunday when my 3 older sisters and I were out for a walk I had my photo taken near a brook .\r\n',
#  u'I still have the photo .\r\n',
#  u'The brook was about 8 feet wide .\r\n',
#  u'The water was about 2 feet deep .\r\n',
#  u'But they|there was 6 feet off|of wet slimy mud I was the first to cross the bridge it broke and in I went .\r\n',
#  u'I slolly|slowly sank in the mud my 2 youngest sisters ran home but my oldest sister stoped|stopped and saved my life she held my head above water untill|until my sisters got home and told my parents .\r\n',
#  u'then they raced down to the brook dad have|had a hell of a Job pulling me out as the mud held me down eventually his|he got me out and carred|carried me home .\r\n',
#  u'my clothes had to me|be distrod|destroyed it took seven bath|baths to get me clearn|clean .\r\n',
#  u"Im|I'm am never alloud|allowed to sit up and watch programes|programmes not surtebull|suitable for children one night when dad was digging the garden mum had gone out , they|there was a film on TV unfitt|unfit for children I sat and watched it , it was all murder and killing , men were being hung and other|others were being shot or stabed|stabbed .\r\n",
#  u'men had their heads cut in half .\r\n',
#  u'My work on a farm I have live on a farm all off|of my life , I am not bosting|boasting but I think I know a fair bit about farming .\r\n',
#  u'I know most about cattle and only a little about machinery .\r\n',
#  u'Some people say farming is the lowest payed|paid and hardest working imployment|employment out .\r\n',
#  u'I agree with those people .\r\n',
#  u'but I would rather work for my living , than just siting|sitting in a stufy|stuffy old office adding up numbers all day or whatever they do .\r\n',
#  u'Give me the open air life .\r\n',
#  u'My father is a farm stockman and I hope to take on the same Job when I leave school .\r\n',
#  u'I am going to take my apprentiship|apprenticeship course when I leave at easter .\r\n',
#  u'that means that I go to classis|classes ones|once a week .\r\n',
#  u'I will learn a lot more about farming and if I pull through the course I will be a usfull|useful chap about the farm .\r\n',
#  u'Will|While I am taking my course I will be get|getting 17 shilling|shillings less than the boy worker that is not taking the course .\r\n',
#  u'But when I am 17 and finished my Apprentiship|Apprenticeship I will get 10 % more than the average pay off|of a boy my age .\r\n',
#  u'Many people asked me why I have choosen|chosen farming as my future carrer|career .\r\n',
#  u'( 1 ) I will be in the open air .\r\n',
#  u'( 2 ) I will be doing a diffrent|different Job every day ( 3 ) I am not interested in enthing|anything else .\r\n',
#  u'For the last 2 or 3 years I am have been work|working on the farm in the holidays .\r\n',
#  u'And I can tell the men I have worked with have been good and give|given me a few tips .\r\n',
#  u'my dad has told quite a lot about farming which I know will help when I life|leave school .\r\n',
#  u'So if anybody want|wants an open air life , choose FARMING\r\n',
#  u'5 .\r\n',
#  u'ANN BARLEY page 81\r\n',
#  u'Dear Rose\r\n',
#  u'I hope you are alright .\r\n',
#  u'I am writing to tell you about my English I have done with Mr David Hollbrook .\r\n',
#  u'He is all_ways|always making me write letters or stories .\r\n',
#  u'I know English will done|do me more good when I leave school .\r\n',
#  u'But some_thime|sometimes I get very bored .\r\n',
#  u"Mind you I'm not very good at English but I try .\r\n",
#  u'Love and Best Wishes Ann\r\n',
#  u'Dear Mr Hollbrook , I hope you will soon get better and come back to school and teach us Have you marked the Exams papers .\r\n',
#  u'I hope this letter will cheer you up .\r\n',
#  u'All the class were sorry to hear you had flu .\r\n',
#  u'Well soon get better you|yours sincerely Joan Stall and Ann Barley 3C\r\n',
#  u'My family\r\n',
#  u'They|There are eight in my family two boy and four girl a|and one mum and one dad I have one sister engaged she will not get married yet because she is only 17 years old she has a boy from Melton His name is Michael Coote and he is 19 My dad works on a farm and one of my brother|brothers works in a garage and the little one goes to the primary school Bridgebrook one of my sister|sisters come|comes to the college and one at the primary .\r\n',
#  u'my biggest one works at the Handsome Half-hose|_?_ my brother and sister which goes out to , work go at 7 in the morning and come home at 7 at night .\r\n',
#  u'My life when I leave school When I leave school I would to work in a bookbinding at Tonbury where all nice boys .\r\n',
#  u'I should like to get married when I am 20 and have two children And a nice handsome husband with nice wavey|wavy hair and a nice big house I would not like to have argument with my husband and always talk nice to him and he talk nice to me .\r\n',
#  u'I should not like a fast boyfrend|boyfriend like some of the girls .\r\n',
#  u'I would like one nice and steady .\r\n',
#  u'When I have my children I would leave the book binding and look after the children .\r\n',
#  u'I would marry a man who likes children not a man that hate|hates children .\r\n',
#  u'I should like twins two of each or one of each .\r\n',
#  u'I should like to get married in a white gown and carry a prayerbook|prayer-book have two big bridesmaids and two little bridesmaids and one pageboy .\r\n',
#  u'I would like to dress my children in the same colur|colour colhes|clothes I should like a boyfriend with a car so that we cane go out for ride .\r\n',
#  u'I like to go on holiday to the seaside and a honeymoon Touring all round the place .\r\n',
#  u'The End .\r\n',
#  u'Poem 1 One , two , three , four , As I am counting up the shore Of course the shore is at the sea , One , two , four , three .\r\n',
#  u'Two large birds Sat on a fence , And they heard They were dence|dense\r\n',
#  u'TWO PEOPLE CHARTORS|CHARACTERS Jean Joyce\r\n',
#  u"SCENE I Two teenager girls at the top of the village when a boy comes along and ask|asks them for a date at seven O'clock .\r\n",
#  u"The boys|boy's name is John seagull .\r\n",
#  u'The two girls are mucking about on the top road .\r\n',
#  u'The boy was going by on a motor bike .\r\n',
#  u'30 one Sunday afternoon .\r\n',
#  u'in the winter .\r\n',
#  u'The boy said " shall we go for a walk .\r\n',
#  u'So he ask|asked he|her again .\r\n',
#  u'So Joyce said I would like to .\r\n',
#  u'Now I will have something to do in the evening .\r\n',
#  u'Joyce said I am glad I am going out with you because it was boring sitting at home in the evening doing nothing .\r\n',
#  u'Jean already had a boyfriend she was waiting for her boyfriend to come he has a car .\r\n',
#  u'Joyce said hear|here come|comes Roy Jean .\r\n',
#  u'John said .\r\n',
#  u'" Whos_evers|Whoever\'s Roy , Joyce said that is jeans|Jean\'s boyfriend .\r\n',
#  u'They never did go for a walk .\r\n',
#  u'Joyce has no brothers or sisters .\r\n',
#  u"Joyce|Joyce's prarents|parents said who_evers|whoever's this with Joyce .\r\n",
#  u'Joyce introduced John to her prerents|parents they said glad to meet you .\r\n',
#  u'John said shall we do|go to the picture|pictures .\r\n',
#  u"Joyce said yes can Roy and Jean come if you want so Joyce and John walk|walked down the road to Jeans|Jean's house .\r\n",
#  u'the|he asked Jean and she said yes please .\r\n',
#  u'So Roy said shall we go in the car .\r\n',
#  u'So they said if you like , " John said I will pay for you to go to the pictures .\r\n',
#  u'Roys|Roy said " What time are we going .\r\n',
#  u'John .\r\n',
#  u"said well the pictures starts at 6.30 and ends at 10.30 so if we go about 6 . O_clock|o'clock that will be alright .\r\n",
#  u"They had they|their tea and when it was time to go they said cheeroh|cheerio want|don't be late .\r\n",
#  u'They got to the pictures they got out of the car and went through the picture door they paid they|the man : they sat down and the film started .\r\n',
#  u'They put there|their arms around each other and John said will you kiss .\r\n',
#  u'Joyce said if you like .\r\n',
#  u'it was the end of the film they just walked out and go|got into the car .\r\n',
#  u'Jean said what did you think of the film you two .\r\n',
#  u"they said it wasnt|wasn't too bad what did you think of it .\r\n",
#  u'Jean said .\r\n',
#  u'" I really enjoyed my_shelf|myself .\r\n',
#  u"They stop|stopped outside Joyce|Joyce's house .\r\n",
#  u'John went and had some supper .\r\n',
#  u'And then he went home .\r\n',
#  u'Joyce kissed him Goodnight and he kissed her Goodnight .\r\n',
#  u'and then he went on his Motor-bikes|Motorbike .\r\n',
#  u'When he got home he told his Mother and father that he had a beautiful girlfriend So there|they said " you will have to bring her to show us .\r\n',
#  u'Joyce said alright .\r\n',
#  u'I will bring her tomorrow .\r\n',
#  u'So John told her the next tonight|night and Joyce said I would love to meet your parents .\r\n',
#  u"So they sent|went ove|over John|John's House .\r\n",
#  u'John introducted|introduced Joyce to her Mother John Mother said Glad to Meet you , and then his father he said the same .\r\n',
#  u'they started to talk and and dicide|decided to get engaged and Marrid|Married the spicil|special is March 4th 1961 .\r\n',
#  u'and they|the engagement is Dec 25th 1960 .\r\n',
#  u'On Christmas day .\r\n',
#  u'There|Their enagement|engagement soon came .\r\n',
#  u'They are enaged|engaged now .\r\n',
#  u'Many People gave them wedding presents John kept the present|presents at his house .\r\n',
#  u'but he got two|too many that Joyce had to go keep some of them because John had no more room .\r\n',
#  u'The day came and for they|the wedding John arrived first and then Joyce when Joyce got up to John they both walk|walked up to the steps .\r\n',
#  u'The wedding is over they had they|their photos .\r\n',
#  u'taken and they went to the hall and had they|their party .\r\n',
#  u'And the People all said Congratulations to you two they both said Thank you .\r\n',
#  u'They decider|decided to have two chidren|children .\r\n',
#  u'The End .\r\n',
#  u'Pop star My best pop singers are Cliff Richard and Adam Faith and Mark Wryer .\r\n',
#  u"The song I like Cliff to sing is Falling in love and Adam|Adam's best song is want|what do you want if you don|don't want money and I have not heard Mark sing yet The best group are the Beverly sisters and the Everly Brothers Cliff and Adam and Mark are not married .\r\n",
#  u'As I looked at this picture it made me think the people were druck|drunk .\r\n',
#  u'The people throw the thinks|things on the floor .\r\n',
#  u'The woman put the baby in the chair in the corner so that they can have a sleep .\r\n',
#  u'They opened the window to let the fresh air in .\r\n',
#  u'This picture we|was panted|painted in the olden days .\r\n',
#  u'It was dark in the house but not out_side|outside .\r\n',
#  u'It looks to me as if it was raining .\r\n',
#  u'The dog is licking up the scraps .\r\n',
#  u'The bird is up in his cage wondering what is happing|happening .\r\n',
#  u'Look at the old fashion|fashioned shoes .\r\n',
#  u"They|Their socks come up to the top of they|their legs like long grandpas|grandpa's pants .\r\n",
#  u'One of the children are playing with the fire .\r\n',
#  u'When a woman looks in her Pram\r\n',
#  u'One day a young woman went down the street to do her shopping .\r\n',
#  u'She went into the shop to order her weekly meat , of course she left her baby out_side|outside the shop .\r\n',
#  u'Her baby was still sitting her its pram , but the little baby was crying .\r\n',
#  u'the little baby could not talk much he could say little words .\r\n',
#  u'So she said " thank you very much for telling me , and said " goodbye So the lady walk|walked on with her baby .\r\n',
#  u'The Lady went in , and while she was in the man changed babys|babies .\r\n',
#  u'So he had the white one and she had the black one , of course he ran away , no one saw him .\r\n',
#  u"She came out of the Baker's and looked in her pram a saw the baby asleep .\r\n",
#  u'She went home a|and while the baby was a_sleep|asleep she done some jobs .\r\n',
#  u'When she had done her jobs she said to herself " the babys|baby is having a long sleep .\r\n',
#  u'I go and see if he is still asleep .\r\n',
#  u'She opened the down|door and she sow|saw a black baby sitting in her pram she shouted .\r\n',
#  u'after she had shouted she put on her coat and went and phone|phoned the police .\r\n',
#  u'The police said they would be here in a very few minetes|minutes .\r\n',
#  u'As soon as she had a knock on the door , she said " Come in , " it was the policemen .\r\n',
#  u'The police said , " What can we do for you Miss .\r\n',
#  u'So she said " This is not my baby I had a white one so the police said when did you first find out she said just a minute ago .\r\n',
#  u'Just before before I phoned you .\r\n',
#  u'( she was crying ) The other policeman said .\r\n',
#  u'" tell us the whole story " So she told them to sit down aud|and asked them if they wanted a cup of tea they said yes .\r\n',
#  u'So she put on the kettle and then sat down and told then|them the story about her baby .\r\n',
#  u'And the police said they would try and find her own baby .\r\n',
#  u'The women|woman was very upset .\r\n',
#  u'And one day the two polce_men|policemen came to her house holding a white baby .\r\n',
#  u'So the women|woman grab|grabbed the baby and said thank you very much for finding him .\r\n',
#  u'I will give you # 5 ponds|pounds reward .\r\n',
#  u'the policemen took the # 5 ponud|pounds and shared it .\r\n',
#  u'And the old woman lived happy ever after and all_ways|always took her own baby were_ever|wherever she went .\r\n',
#  u'The end .\r\n',
#  u'She had a boyfriend and so did he want to get married .\r\n',
#  u'The big day came she was a bit nervous .\r\n',
#  u'She got up to the church and walked in with her father and stood up the alter|altar with her boy_friend|boyfriend .\r\n',
#  u'She were still nervous and so was he his knees were hitting together .\r\n',
#  u'there were all tins and shoes tired|tied on the back of the car and JUST MARRIED wrote on the window with lipstick .\r\n',
#  u'All the people went back into the room and started clearing up .\r\n',
#  u'they enjoyed living by they_self|themselves .\r\n',
#  u'one day they had a serious talk thinking about having a family of they|their own .\r\n',
#  u'One day it happen|happened she was pregant|pregnant So when she told him he was pleased he said I am pleased you are having a baby .\r\n',
#  u'So they went to they|their parents and told them the news .\r\n',
#  u'he was a bonny boy , , they were both fond of him .\r\n',
#  u'After that she had two more , and when they all grew up they all had familys|families of their own .\r\n',
#  u'6 .\r\n',
#  u'WILLIAM GLEBE page 90\r\n',
#  u'AN APPLE\r\n',
#  u'when you go pinching apple|apples you do not want to take to|too many people or you will not get away so quick when there are a lot of people with you a_specally|especially little boys they make too much noise .\r\n',
#  u'If you pick apples off of the ground you have to be carful|careful of the wasps or else they will sting you and the sting comes up to a big bump where_ever|wherever it stings you .\r\n',
#  u'when you are by yourself and some_one|someone comes and you have to climb over the barb|barbed wire and get caught the man will probally|probably catch you but if someone else is with you they can unhook you .\r\n',
#  u'some people when the|they catch you they might hit you and said|say he will hit you harder next time he catches you .\r\n',
#  u'But some people say they will hit you next time but warn you not to come in the orchard again But the children could not resist getting some more apples to eat .\r\n',
#  u'It is best getting apples from an orchard where there are no houses .\r\n',
#  u'I never take a dark jacket or a red one because you will be reconnised|recognized very easy because red shows up very easy .\r\n',
#  u'The Fox The fox is a sly old beast He sits in his den cleaning and waiting To make a_nother|another savage attack He walks the field to the farm The smell of chickens in the passing breeze .\r\n',
#  u'He makes a leap .\r\n',
#  u'Chickens cackle as the fox collects his meal .\r\n',
#  u'WINTER When the snow lay round about The robins come out to seek crumbs Their feet are numb But the snow still lies round about .\r\n',
#  u"A tree is a place for song That's where birds sing their sweet song .\r\n",
#  u'The leaves have gone .\r\n',
#  u'It will not be long before the tree has gone .\r\n',
#  u'Stranden|Stranded on a Desert Island\r\n',
#  u"One midsummer's|midsummer day at 9.30 a.m.\r\n",
#  u'a ship was wrecked by a corral|coral reef so people jumped overboard .\r\n',
#  u'People who could not swim did not know it was a case of life or death The ship was sinking fast but some still hung on .\r\n',
#  u'the shore was only about a mile away so some began to swim to the shore .\r\n',
#  u'Getting food from the ship was impossible but some people on the ship could get down to the store room and get some diving out_fits|outfits .\r\n',
#  u'So one man volonteered|volunteered to swim out to the ship and go down to the store room .\r\n',
#  u'Their|There were dead bodys|bodies on the deck within 20 minutes of the ship_wreck|shipwreck .\r\n',
#  u'Their|There were 1 or 2 live people on board but he was frightened to go on the island .\r\n',
#  u'The man who swam from the island went down to the store room .\r\n',
#  u'He held his breath as he went down below the surface of the water .\r\n',
#  u'As he open|opened the store room door the water gushed in very quickly .\r\n',
#  u'So he had to feel for the diving suits .\r\n',
# ...
#  u'The lady who took the baby saw it in the paper she became a bit worred|worried of this and got very nerves|nervous she through|threw the paper down .\r\n',
#  u'She did not now|know the police will ask her wha\'t|what have you got in that baskek|basket " " I have some dirty washing I am going to thack|take them to the lordery|laundry .\r\n',
#  u'and the ladys|lady who|whose baby was stowle|stolen got her baby back safaly|safely .\r\n',
#  u'13 .\r\n',
#  u'KENNETH PRIME page 137\r\n',
#  u"Beat for the drew|draw ` Bankg|Bang ' bullet Mr Macdillon its Mac Plester in the HEART Dead staidght|straight away Macdillon fire his gun Bankg|Bang Bankg|Bang Bankg|Bang Doc H he is dead Kitty Macdillon yes Kitty yor|your Brother is Dead .\r\n",
#  u'THE END THE END\r\n',
#  u'There are 7 of Us there is my mum and my sister thre|there is Peter and Andrew and Alan and my_self|myself and my bad|dad .\r\n',
#  u'By|My bad|dad is a elecenician|electrician man .\r\n',
#  u'Mum dus|does housee_work|housework .\r\n',
#  u'I go to the pictures kneeling|nearly every night .\r\n',
#  u'Wiich|Which way to go to the bank mate .\r\n',
#  u'I went in to the bank I give Him a Forged Note .\r\n',
#  u'And the bank man said this is a Forged Noet|Note He said weight|wait Here I will Be Back in 10 mine|minutes Sir .\r\n',
#  u'He came Back wiht|with to|two policeman|policemen they took me in a police car I went to prison .\r\n',
#  u"A lady is a man|man's best fenird|friend A lady Fat and Thin is a Dog|Dog's best fenird|friend a PLENTY is my best friend .\r\n",
#  u'I like Lady nice and Sexy with PLENTY of bod|body .\r\n',
#  u'and not to|too driy|dirty and not to|too rude .\r\n',
#  u'I know a little mouse who said to a_nother|another little mouse come round the corner I will show you my hole .\r\n',
#  u'One day a man kill a womon|woman .\r\n',
#  u'and cut Her Kidney|Kidneys out and eat|ate them .\r\n',
#  u'next day He kill|killed a another woman and cut her kidney|kidneys out and eat|ate them . and made an awful mess .\r\n',
#  u'He was called the vampire .\r\n',
#  u'He hab|had to|two horrible teeth\r\n',
#  u'a wamon|woman was kill|killed and a kidney was missing .\r\n',
#  u'it was getting serious .\r\n',
#  u'Nexe|Next they find the body was on marshladn|marshland and foodprints|footprints in to swamp\r\n',
#  u"hon|on the motor cruiser there was shm|some Frogmen's suits .\r\n",
#  u'the captman|captain he thc|took hus|us hot|out to sea we Put hn|on out|our suits we wet|went down in to the sea hon|on the bottom .\r\n',
#  u'he go hon|on to the Radio we tod|told the sea Command .\r\n',
#  u"he tod|told the motor disposol|disposal thror|they come to the side of the ship thrar|they pht|put on the Frgmens|Frogmen's suits and wet|went down thaw|there fo|for the mine thrar|they cut the choin|chain which hasld|held the motor floated to the top thrar|they fired a rifle which hit 1 of the horn|horns hit|it blew up so we wit|went home .\r\n",
#  u'One day a buy|boy her|heard is|his mother and Father arguing and he decided to runaway|run_away .\r\n',
#  u'To Aunty and unlce|uncle in Suothwode|Southwold .\r\n',
#  u'The orphaned Family\r\n',
#  u'In the orphaed|orphaned Family thrar|there was 6 Boy|Boys .\r\n',
#  u'One day the Boy|Boys wnet|went to payer|play in the wood and mayd|made a dener|den and Fiyer|Fire then a Frameman|Farmer he had a gon|gun he fiyed|fired his gun and hiter|hit one of Boy|Boys The ophoned|orphaned Boy pit|beat im|him up .\r\n',
#  u'and wet|went home Doc_chm|_?_ and the Boy that was sot|shot wos|was or_rit|alright .\r\n',
#  u'The HED|END\r\n',
#  u'As he passed the on his way home fom|from the Dance he heard a muffled explosion I sor|saw that the dor|door was oped|opened I wocer|walked in wend|went dau_sosys|downstairs and sor|saw a holler|hole in the saffrery|_?_ I wet|went hover|over I feod|found the pelser|_?_ and thoy|the cHmer|_?_ I went home the EDH|END\r\n',
#  u'14 .\r\n',
#  u'ROBERT SHIRE page 147\r\n',
#  u'One day a boy stood leaning against the cafe door named rex harrison .\r\n',
#  u'He had Black hair with Brown eyes with red Jacket , Grey trousers with black shoes .\r\n',
#  u'He was waiting for Jean smith she is 16 Brown hair , brown eyes , they went inside the cafe , then they talked to each other then Jean said I am going out with another boy , but I can get audrey for you Rex , said all right .\r\n',
#  u'I will tell her to meet you outside the cinama|cinema at 6.39 .\r\n',
#  u'Audrey is a blonde she is 16 they went inside the cinama|cinema Jean went in with them when the film was nearly over when Jean went of|off to see her own boyfreind|boyfriend and left rex and audrey were left a_lone|alone in the cinama|cinema the next 6 months they went to the pictures then they got ingaged|engaged .\r\n',
#  u'after they got ingaged|engaged .\r\n',
#  u"they went to the seaside for the day at Blackpool they got there at eleven oclock|o'clock saturday morning they got out of the train .\r\n",
#  u"then they went to catch the bus for home they got home at nine oclock|o'clock Rex kissed audrey then they went home in the morning Rex went to work at the television studios Audrey went to work in the cafe when they got home from work the next saturday they got married .\r\n",
#  u'The End .\r\n',
#  u'The unispected|unexpected trip across the sea\r\n',
#  u'Once upon a time there was a boy named Peter .\r\n',
#  u'He went to the harbour he was very tired so he saw a ship he got on board the ship , he crept down to where the cargo was kept he got in a comvatable|comfortable place to sleep .\r\n',
#  u'He woke up 6 hours later he got out of the cargo store crept up on Deck and all he could see was the sea the boat had left the harbour and it was due for china .\r\n',
#  u'he crept|crapped back to the cargo sat , wondering what he would do next then he laid|lay down and went to sleep again when the men came down to fetch the cargo .\r\n',
#  u'They saw the boy they took him for to the captain .\r\n',
#  u'Then the captain said to the boy what are you doing hear|here I run away from home I was very tired .\r\n',
#  u'I see this boat so i creeped|crept on board , and had a sleep .\r\n',
#  u'The captian|captain said I will let you stay abroard|aboard the ship as long as you work for your keep .\r\n',
#  u"The boy said all right ile|I'll work .\r\n",
#  u'The captain said go with the men to shift the cargo so he went to the cargo store they lifted all the cargo to another place , then they had to scrub the deck when they had finished that they saw china in the distance he wondered what it would be like .\r\n',
#  u'The captain said it will be all right you will not go of|off this ship by next week you will be back home .\r\n',
#  u"The boy said I dont|don't want to go hime|home , if I do i will get killed .\r\n",
#  u"The police will see that you dont|don't get belted on December 10th they were in england , and the boy was home with his parents .\r\n",
#  u'The End .\r\n',
#  u'The Rat\r\n',
#  u'The rat is a dirty creature it digs tunnels under the ground at night it goes in the chicken hut looking for meal and wheat then it goes to sleep .\r\n',
#  u'The mouse\r\n',
#  u"The mouse is a slimy fellow , its|it's not very big but it squeezes through tiny cracks in wood its|it's got very sharp teeth and a slimy tail and its little ears prick out of the hole it likes meal .\r\n",
#  u'The Mouse\r\n',
#  u'The mouse is a little fellow it lives amongst straw and sometimes a pile of bags or in any old heaps of rubbish etc .\r\n',
#  u'it makes a runaway|runway through rubbish and into meal bins where it eats the meal and soon as anybody comes , it jumps out of the meal bins along its runway and back in is|its nest .\r\n',
#  u"The hare came running down the hill With a flash of brown its|it's down the hill its Big brown ears prick out of the corn resting all day and playing all night with its little fluffy tail dragging behind that crafty old hare laying|lying in the barley\r\n",
#  u'The Tramp .\r\n',
#  u'The tramp is a funny man He walks all over the place He sleeps under a hedge He has got a pair of baggy socks A pair of trousers with holes in it And a grubby Jacket not worth twopence He eats scraps of meat with a piece of bread Then he goes on his way Like a funny man\r\n',
#  u'15 .\r\n',
#  u'GERALD GOODCHILD page 151\r\n',
#  u'MY FAMILY\r\n',
#  u'There is a man look|looking for a job is|his name is John WIGGLE is|his hair is Black is|his eye|eyes are Blue he is a big strong man he is walking down the street he is going into the lorry department he has just come out of the lorry depatment|department .\r\n',
#  u'he look|looks very Please|Pleased he start|starts work to_morrow|tomorrow .\r\n',
#  u'he is going home to tell is|his wife and kids .\r\n',
#  u'morring|morning come|comes he get|gets up at 5 am he get|gets realy|ready for work he has go|got to be there are|at 6.30 am and he get|gets to work the Bos|Boss said to him take some_thing|something down the|to my house and put then|them in the garage and he went the lot of time with load he go|got suspicious and he went to the poicle|police and they gave him a Reward and the poicle|police we will go up ther|there to get him and the poicle|police go|got him and John became the bos|boss of the lord|lorry departent|department .\r\n',
#  u'The jungle\r\n',
#  u'In the jungle there are all kinds of animals .\r\n',
#  u'There are snake|snakes apes etc .\r\n',
#  u'One day a little white boy was with is|his Mother .\r\n',
#  u'And the boy said to his mother can I go for a walk .\r\n',
#  u"She said yes but dont|don't go into the jungle .\r\n",
#  u'and he yes mother and he was walking along the path and he see|sees a chimpanzee and he went to play with it .\r\n',
#  u'and he was play|playing with chimpanzee .\r\n',
#  u"and suddenly an ape pick|picked him up and carried him a_way|away the and the little boy was shout|shouting help help and the boy|boy's mother was getting worried it was getting dark and there|her Husband came run|running and he said were|where is Gerald I don|don't on|know he went of|off for a walk and has not come back oh john I am worried .\r\n",
#  u'I will gett|get a party of man|men and go and seach|search for him .\r\n',
#  u"and they went to look of|for the boy and they look|looked evry_were|everywhere they find|found him sleeping with the ape and the boy|boy's father said come on home Gerald and the little said cane|can I take ape home Dad and is|his say on|no and the little said I won|won't come home all right then .\r\n",
#  u'He lay on the bed in a dream he like cold ice-cream went|when he was alive he jump up and down like a machine he white in the face cold in the eyes he lie waiting for his long box hear|here comes slow has|as can be they slowly put him in slow slow slow he goes down down deep under the earth\r\n',
#  u'THE HEADLESS BOdy\r\n',
#  u'One dark night in midwinter There was woman walking down a dark ally|alley and suddenly someone jump|jumped one|on her she screamed .\r\n',
#  u'But it was no good there was not any_one|anyone around she fell to the ground she was dead dead as door it was a man that jump|jumped on her he was mental .\r\n',
#  u'He took her to is|his house he took her in a dark room switch|switched on the light he cut of|off her head and arms and legs .\r\n',
#  u'He got a big trunk and put the body into the trunk he put the head in the park morning came not_one|no_one had miss|missed the woman two boy|boys were walking through the park one of the boys run|ran into the three|tree senddly|suddenly he shout|shouted Bob come hear|here " what want " " come hear|here quick " " I am come|coming " " got|go and get the police quick " Be Back in a minute " he came Back with the police .\r\n',
#  u'the police said it was a murder case a head with_out|without a body .\r\n',
#  u'HE sent the trunk to Melton station it had no name or nothing it stop|stopped there for six week|weeks no one came for it so at the station they had a talk and said they would open it .\r\n',
#  u"they opon|opened it they saw the body with the arm and legs of|off they call|called the police the police came the body was naked this must be the body that the head belong|belongs to they took it down to the station and had it examined the body they found jack the ripper|ripper's finger prints on the body so they started to look for Jack the ripper they look|looked and look|looked every_were|everywhere and one day they go|got a lead and they look|looked for him and they went up to room 19 and the police said Jack this is the police out the door they knock|knocked the door down Jack has go|gone out of the window there he go|goes half|after him man they go|got him down a back ally|alley he call|could not get away ther|he was change|charged with murder he died in prison 6 year|years a_go|ago it was 1897 .\r\n",
#  u'Work at Butcher\r\n',
#  u'I work at a Butcher shop in Bridgebrook .\r\n',
#  u'I work for Mrs Tate the paid|pay it is quite good .\r\n',
#  u'I go out on a round saturday I still at school I work two night|nights a week and all day Saturday I can drive I turn the van round in the yard my mate is Stanlay|Stanley he drive|drives the van round .\r\n',
#  u'I can cut meat up there are a lot of different meats .\r\n',
#  u'There is stack|steak , frying stack|steak , stawing|stewing stack|steak , Pudding bf|beef , kid , lamb chop , pork chop , etc .\r\n',
#  u'My Dad work were|where do .\r\n',
#  u'he is a big hefty man went|when I go two night|nights a week I wash up .\r\n',
#  u'Mrs Tate has a abattoir to|too I have some good frend|friends at the shop there is Tomy|Tommy , Gordon , Andrew , Gordon has and|an Ariel colt , Andrew has Ariel Leader .\r\n',
#  u'I have go|got a bluestreak pusbycile|push-bicycle I was go|going to work to_night|tonight but we have go|got a party a|at school I will go THursday night we get paid Saturday night .\r\n',
#  u'16 .\r\n',
#  u'JUDITH WARD page 157\r\n',
#  u"Then he saw his friend in the distance , he|her name was Jean Smith , she was very attractive but she already had a boy so there was no good ever waiting for her , when Jean got to the Cafe door , she was very surprised to find Rex there , and she said my goodness you do look glum today whats|what's the matter , said Jean .\r\n",
#  u'in the Hall\r\n',
#  u'" Well " were|we\'re in here now , lets|let\'s go and get a table , ah theres|there\'s one over there said Leon , OK lets|let\'s go and sit down , I\'ll go and get some drinks said Rex ,\r\n',
#  u'After the Drink\r\n',
#  u'When I leave School\r\n',
#  u'I am going to leave school at 15 , at Easter , 1962 , and I shall work for two years at least before I think about getting a boy .\r\n',
#  u'I want to get married at 20 , so that I will have about three years to get engaged , and to get to know each other .\r\n',
#  u'I wand|want two children , one of each or twins .\r\n',
#  u'I also want to live in a bungalow I want a man with lovely black or brown wavey|wavy hair not much taller than me .\r\n',
#  u'I want a man that likes children and takes them out , and plays with them .\r\n',
#  u'Then we will all be able to go out and enjoy ourselves .\r\n',
#  u'I shall stop nursing when I get married , after I have had a child , then I may do part-time work .\r\n',
#  u'I want to get married in white .\r\n',
#  u'I want to go abroad for my honeymoon .\r\n',
#  u"For the first summer holiday , I would like to go to Butlin's holiday camp .\r\n",
#  u'For my children I would like a blue and white or Black pram .\r\n',
#  u'Stephen asked me if I would like to go , so he bought two tickets for him and me , and we went in and Pauline and Trevor were sitting in there holding hands .\r\n',
#  u'the best boyfriend I ever had .\r\n',
#  u'and so Stephen left .\r\n',
#  u'But we still send letters and post_cards|postcards to each other .\r\n',
#  u'So that we still remember each other .\r\n',
#  u'So I got ready and set off to the station .\r\n',
#  u'They said that they would put up notices about the baby .\r\n',
#  u'They let me look after him until someone owned up .\r\n',
#  u'A month later .\r\n',
#  ...]

# %%
import nltk as nk
nk.download('all')
# Out:
# [nltk_data] Downloading collection u'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/biocreative_ppi.zip.
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package brown_tei to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_esp.zip.
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/city_database.zip.
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/comparative_sentences.zip.
# [nltk_data]    | Downloading package comtrans to /root/nltk_data...
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2002.zip.
# [nltk_data]    | Downloading package conll2007 to /root/nltk_data...
# [nltk_data]    | Downloading package crubadan to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/crubadan.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dependency_treebank.zip.
# [nltk_data]    | Downloading package dolch to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dolch.zip.
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/europarl_raw.zip.
# [nltk_data]    | Downloading package floresta to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/floresta.zip.
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v15.zip.
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v17.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package ieer to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ieer.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package indian to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/indian.zip.
# [nltk_data]    | Downloading package jeita to /root/nltk_data...
# [nltk_data]    | Downloading package kimmo to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/kimmo.zip.
# [nltk_data]    | Downloading package knbc to /root/nltk_data...
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/lin_thesaurus.zip.
# [nltk_data]    | Downloading package mac_morpho to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mac_morpho.zip.
# [nltk_data]    | Downloading package machado to /root/nltk_data...
# [nltk_data]    | Downloading package masc_tagged to /root/nltk_data...
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/moses_sample.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package nombank.1.0 to /root/nltk_data...
# [nltk_data]    | Downloading package nps_chat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nps_chat.zip.
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/omw.zip.
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/opinion_lexicon.zip.
# [nltk_data]    | Downloading package paradigms to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/paradigms.zip.
# [nltk_data]    | Downloading package pil to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pil.zip.
# [nltk_data]    | Downloading package pl196x to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pl196x.zip.
# [nltk_data]    | Downloading package ppattach to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ppattach.zip.
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/problem_reports.zip.
# [nltk_data]    | Downloading package propbank to /root/nltk_data...
# [nltk_data]    | Downloading package ptb to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ptb.zip.
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_1.zip.
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_2.zip.
# [nltk_data]    | Downloading package pros_cons to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pros_cons.zip.
# [nltk_data]    | Downloading package qc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/qc.zip.
# [nltk_data]    | Downloading package reuters to /root/nltk_data...
# [nltk_data]    | Downloading package rte to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/rte.zip.
# [nltk_data]    | Downloading package semcor to /root/nltk_data...
# [nltk_data]    | Downloading package senseval to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/senseval.zip.
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentiwordnet.zip.
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentence_polarity.zip.
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sinica_treebank.zip.
# [nltk_data]    | Downloading package smultron to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/smultron.zip.
# [nltk_data]    | Downloading package state_union to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/state_union.zip.
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/subjectivity.zip.
# [nltk_data]    | Downloading package swadesh to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/swadesh.zip.
# [nltk_data]    | Downloading package switchboard to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/switchboard.zip.
# [nltk_data]    | Downloading package timit to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/timit.zip.
# [nltk_data]    | Downloading package toolbox to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/toolbox.zip.
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package udhr to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr.zip.
# [nltk_data]    | Downloading package udhr2 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/unicode_samples.zip.
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package verbnet to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet.zip.
# [nltk_data]    | Downloading package verbnet3 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet3.zip.
# [nltk_data]    | Downloading package webtext to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/webtext.zip.
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet.zip.
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package ycoe to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ycoe.zip.
# [nltk_data]    | Downloading package rslp to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/rslp.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/universal_tagset.zip.
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/book_grammars.zip.
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/sample_grammars.zip.
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/spanish_grammars.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/large_grammars.zip.
# [nltk_data]    | Downloading package tagsets to /root/nltk_data...
# [nltk_data]    |   Unzipping help/tagsets.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/bllip_wsj_no_aux.zip.
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/word2vec_sample.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package mte_teip5 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mte_teip5.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping misc/perluniprops.zip.
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nonbreaking_prefixes.zip.
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package porter_test to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/porter_test.zip.
# [nltk_data]    | Downloading package wmt15_eval to /root/nltk_data...
# [nltk_data]    |   Unzipping models/wmt15_eval.zip.
# [nltk_data]    | Downloading package mwa_ppdb to /root/nltk_data...
# [nltk_data]    |   Unzipping misc/mwa_ppdb.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
data = []

#lines = open("holbrook.txt").readlines()
for i in range(len(lines)):
    if "|" in lines[i]:
        lines_in_arr = nk.word_tokenize(lines[i].encode('ascii', 'ignore'))
        initial_data = {
            'original': list(lines_in_arr),
            'corrected': list(lines_in_arr),
            'indexes': []
        }
        for j in initial_data['original']:
          if("|" in j) == True:
            index_correction = initial_data['original'].index(j)
            correction_values = j.split("|")
            initial_data['corrected'][index_correction] = correction_values[1]
            initial_data['original'][index_correction] = correction_values[0]            
            initial_data['indexes'].append(index_correction)
        data.append(initial_data)                
    else:
        initial_data = {
            'corrected' : nk.word_tokenize(lines[i].encode('ascii', 'ignore')),
            'original': nk.word_tokenize(lines[i].encode('ascii', 'ignore'))
        }
        data.append(initial_data)

#data = []
# Write your code here

#assert(data[2] == {
#    'original': ['I', 'have', 'four', 'in', 'my', 'Family', 'Dad', 'Mum', 'and', 'siter', '.'], 
#    'corrected': ['I', 'have', 'four', 'in', 'my', 'Family', 'Dad', 'Mum', 'and', 'sister', '.'], 
#    'indexes': [9]
#})

# %%
print(data[164])
# Out:
# {'corrected': ['When', 'you', 'get', 'to', 'the', 'cores', 'inside', 'the', 'cores', 'are', 'pips', 'you', 'throw', 'the', 'cores', 'on', 'the', 'fire', 'to', 'burn', 'then', '.'], 'original': ['When', 'yow', 'get', 'to', 'the', 'corres', 'inside', 'the', 'corres', 'are', 'pips', 'yow', 'thorght', 'the', 'corres', 'on', 'the', 'fire', 'to', 'brun', 'then', '.'], 'indexes': [1, 5, 8, 11, 12, 14, 19]}

# %% [markdown]
# The counts and assertions given in the following sections are based on splitting the training and test set as follows

# %%
test = data[:100]
train = data[100:]

# %% [markdown]
# ## **Task 2** (10 Marks):
# Calculate the frequency (number of occurrences), *ignoring case*, of all words and their unigram probability from the corrected *training* sentences.
#
# *Hint: use `Counter` to implement this so it may be called many times*

# %%
filtering_training_data = []
for tr in range(len(train)):
    filtering_training_data = filtering_training_data + train[tr]["corrected"]
print(filtering_training_data)
# Out:
# ['they', 'can', 'go', 'quite', 'fast', 'this', 'was', 'a', 'Royal', 'Enfield', '_', '?', '_', 'there', 'were', 'some', 'Royal', 'Enfield', 'Racing', 'there', 'as', 'well', 'I', 'saw', 'a', 'Royal', 'Enfield', 'come', 'first', 'it', 'was', 'like', 'mine', '.', 'there', 'were', 'the', 'new', 'Japanese', 'Honda', 'they', 'are', 'very', 'fast', 'and', 'getting', 'quite', 'popular', 'in', 'England', 'I', 'saw', 'one', 'man', 'come', 'off', 'he', 'was', 'on', 'a', 'B.S.A', '.', 'One', 'man', 'had', 'to', 'go', 'in', 'Hospital', 'because', 'he', 'broke', 'his', 'leg', 'another', 'man', 'hurt', 'his', 'arm', 'in', 'a', 'sidecar', 'race', 'I', 'do', "n't", 'think', 'it', 'was', 'much', 'I', 'saw', 'a', 'sidecar', 'turn', 'right', 'over', 'the', 'sidecar', 'man', 'was', 'alright', 'but', 'the', 'motorbike', 'Rider', 'was', 'thrown', 'into', 'the', 'crowd', 'I', 'do', "n't", 'know', 'what', 'happened', 'to', 'him', 'he', 'was', 'hurt', 'quite', 'bad', '.', 'the', 'sidecar', 'broke', 'off', 'the', 'motorbike', 'and', 'spun', 'down', 'the', 'track', 'for', '7', 'yards', 'then', 'hit', 'a', 'man', 'who', 'was', 'on', 'the', 'corner', 'and', 'killed', 'him', 'his', 'hat', 'was', 'blowing', 'down', 'the', 'track', 'the', 'motorbike', 'caught', 'fire', 'and', 'blew', 'up', 'the', 'petrol', 'went', 'all', 'over', 'the', 'track', 'but', 'they', 'soon', 'put', 'it', 'out', 'by', 'sand', 'there', 'was', 'some', 'oil', 'got', 'on', 'the', 'track', 'as', 'well', 'it', 'made', 'it', 'very', 'slippery', 'There', 'were', 'quite', 'a', 'few', 'people', 'there', 'because', 'it', 'was', 'a', 'nice', 'dry', 'day', 'The', 'final', 'race', 'was', 'on', 'there', 'were', '2', 'Royal', 'Enfield', '3', 'Japanese', 'Honda', '1', 'B.S.A', '.', '3', 'Triumph', 'they', 'were', 'on', 'the', 'starting', 'line', 'Bang', 'they', "'re", 'off', 'one', 'BSA', 'is', 'still', 'on', 'the', 'starting', 'line', 'the', 'rest', 'are', 'round', 'the', 'bend', 'I', 'can', 'see', 'one', 'man', 'off', 'he', 'is', 'on', 'a', 'Triumph', 'I', 'think', 'a', 'Japanese', 'Honda', 'is', 'in', 'the', 'lead', 'I', 'think', 'he', 'is', 'going', 'to', 'lead', 'he', "'s", 'won', 'by', '3', 'yards', 'and', 'a', 'Royal', 'Enfield', '2', 'and', 'a', 'Honda', '3', '.', 'The', 'End', 'we', 'went', 'over', 'the', 'football', 'field', 'it', 'was', 'quite', 'wet', 'and', 'soon', 'made', 'my', 'toes', 'cold', '.', 'the', 'grass', 'was', 'quite', 'long', 'now', 'it', 'shone', 'with', 'the', 'dew', 'on', 'it', '.', 'a', 'field', 'ploughed', 'next', 'to', 'it', 'I', 'think', 'it', 'was', 'done', 'yesterday', '.', 'on', 'the', 'other', 'side', 'was', 'a', 'hedge', 'it', 'had', 'a', 'lot', 'of', 'thorns', 'in', 'it', '.', 'they', 'had', 'cleaned', 'the', 'river', 'and', 'made', 'it', 'very', 'wide', 'for', 'the', 'ducks', 'there', 'were', 'some', 'potatoes', 'in', 'the', 'water', '.', 'there', 'were', 'some', 'brussels', 'men', 'sitting', 'in', 'the', 'pathway', 'round', 'a', 'fire', 'we', 'had', 'to', 'go', 'on', 'to', 'a', 'ploughed', 'field', 'to', 'get', 'round', 'them', 'this', 'made', 'my', 'shoes', 'heavy', '.', 'this', 'was', 'quite', 'muddy', 'some', 'boys', 'did', 'not', 'think', 'much', 'to', 'it', 'nor', 'did', 'I', 'but', 'we', 'still', 'went', '.', 'the', 'dew', 'on', 'the', 'brussels', 'leaves', 'made', 'them', 'like', 'pearls', '.', 'Mr', '.', 'Holbrook', 'went', 'over', 'the', 'brook', 'first', 'some', 'were', 'boys', 'going', 'round', 'but', 'only', 'one', 'went', 'after', 'all', 'the', 'rest', 'went', 'over', 'the', 'tree', 'Gerald', 'nearly', 'went', 'in', 'one', 'foot', 'touched', 'the', 'water', 'then', 'we', 'went', 'across', 'the', 'new', 'piece', 'of', 'grass', 'into', 'school', 'we', 'went', 'and', 'cleaned', 'our', 'shoes', 'with', 'paper', 'then', 'the', 'bell', 'went', 'for', 'break', '.', '2', '.', 'JOAN', 'STALL', 'page', '54', 'A', 'poem', 'A', 'little', 'yellow', 'bird', 'sat', 'on', 'my', 'window', 'sill', 'He', 'hopped', 'and', 'popped', 'about', 'He', 'whistled', 'he', 'chi ...

# %%
from collections import Counter

def unigram(word):
    # Write your code here.    
    count_of_word = Counter(w.lower() for w in filtering_training_data)
    return count_of_word[word.lower()]
    

def prob(word):
    # Write your code here.
    count = unigram(word)
    total = 0
    for w in filtering_training_data:        
        total += 1
    return float(count)/total

# Test your code with the following
#assert(unigram("me")==87)

# %%
print(unigram("ME"))
print(unigram("the"))
print(prob("the"))
#[count for w in filtering_training_data if w == "The" count = count + 1]
# u = filtering_training_data.count("me")
# l = filtering_training_data.count("Me")
# c = filtering_training_data.count("ME")
# print(u,l,c, (u+l+c))
# Out:
# 87
# 1334
# 0.061170212766

# %% [markdown]
# ## **Task 3** (15 Marks):
# [Edit distance](https://en.wikipedia.org/wiki/Edit_distance) is a method that calculates how similar two strings are to one another by counting the minimum number of operations required to transform one string into the other. There is a built-in implementation in NLTK that works as follows:

# %%
from nltk.metrics.distance import edit_distance

# Edit distance returns the number of changes to transform one word to another
print(edit_distance("hello", "hi"))
# Out:
# 4

# %% [markdown]
# Write a function that calculates all words with *minimal* edit distance to the misspelled word. You should do this as follows
#
# 1. Collect the set of all unique tokens in `train`
# 2. Find the minimal edit distance, that is the lowest value for the function `edit_distance` between `token` and a word in `train`
# 3. Output all unique words in `train` that have this same (minimal) `edit_distance` value
#
# *Do not implement edit distance, use the built-in NLTK function `edit_distance`*

# %%
def get_candidates(token):
    word_distance = []
    all_word_distance = []
    min_distance = 0
    result = []
    all_unqiue_words = set(filtering_training_data)
    for y in all_unqiue_words:
        word_distance = {
            "word":  y,
            "distance": edit_distance(y, token)
        }
        all_word_distance.append(word_distance)
        if min_distance == 0:
            min_distance = word_distance['distance']
        elif word_distance['distance'] <= min_distance:
            min_distance = word_distance["distance"]

    for j in all_word_distance:
        if j["distance"] == min_distance:
            result.append(j["word"])
    return result
        
# Test your code as follows
#assert get_candidates("minde") == ['mine', 'mind']
get_candidates("minde")
# Out:
# ['mind', 'mine']

# %% [markdown]
# ## Task 4 (15 Marks):
#
# Write a function that takes a (misspelled) sentence and returns the corrected version of that sentence. The system should scan the sentence for words that are not in the dictionary (set of unique words in the training set) and for each word that is not in the dictionary choose a word in the dictionary that has minimal edit distance and has the highest *unigram probability*.
#
# *Your solution to this should involve `get_candidates`*

# %%
def correct(sentence):
    # Write your code here
    split_sentence = sentence
    all_predicted_words = []
    prob_all_predicted_words = []
    mispelled_words = [i for i in split_sentence if i not in set(filtering_training_data)]

    #mispelled_indexes = [split_sentence.index(mispelled_words[word]) for word in range(len(mispelled_words))]
    for word in mispelled_words:
        predicted_words = get_candidates(word)
        for pw in predicted_words:
            predicted_word = {
                "word": pw,
                "probability": prob(pw)
            }
            all_predicted_words.append(predicted_word)
        for apw in all_predicted_words:
            prob_all_predicted_words.append(apw["probability"])
        max_word_prob = max(prob_all_predicted_words)
        split_sentence[split_sentence.index(word)] = [t["word"].lower() for t in all_predicted_words if t["probability"] == max_word_prob][0]
    return split_sentence
  
#assert(correct(["this","whitr","cat"]) = ['this','white','cat'])

# %%
# print(correct(["this","whitr","cat"]) == ['this', 'white', 'cat'])
print(correct(["this","whitr","ct"]))
print(correct(["Enfield"]))
# Out:
# ['this', 'white', 'it']
# ['Enfield']

# %% [markdown]
# ## **Task 5** (10 Marks):
# Using the test corpus evaluate the *accuracy* of your method, i.e., how many words from your system's output match the corrected sentence (you should count words that are already spelled correctly and not changed by the system).

# %%
original_test_data = []
corrected_test_data = []
check_correct_words = []
correct_counter = []
incorrect_counter = []
for te in range(len(test)):
    if 'original' in test[te]:
        original_test_data = original_test_data + test[te]['original']
for te in range(len(test)):
  corrected_test_data = corrected_test_data + test[te]['corrected']

# %%
print(len(corrected_test_data))
print(len(original_test_data))
print(corrected_test_data)
# Out:
# 1136
# 1136
# ['1', '.', 'NIGEL', 'THRUSH', 'page', '48', 'I', 'have', 'four', 'in', 'my', 'Family', 'Dad', 'Mum', 'and', 'sister', '.', 'My', 'Dad', 'works', 'at', 'Melton', '.', 'My', 'sister', 'goes', 'to', 'Tonbury', '.', 'My', 'Mum', 'goes', 'out', 'sometimes', '.', 'I', 'go', 'to', 'Bridgebrook', 'i', 'go', 'out', 'sometimes', 'on', 'Tuesday', 'night', 'i', 'go', 'to', 'Youth', 'club', '.', 'On', 'thursday', 'nights', 'I', 'go', 'bellringing', 'on', 'Saturdays', 'I', 'go', 'down', 'to', 'the', 'farm', '.', 'on', 'sundays', 'I', 'go', 'to', 'church', '.', 'I', 'go', 'to', 'bed', 'at', '10', 'o', 'clock', 'I', 'watch', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house', '.', 'The', 'house', 'is', 'in', 'the', 'world', '.', 'I', 'live', 'at', 'Boar', 'Parva', 'it', 'is', 'near', 'Melton', 'and', 'Bridgebrook', 'and', 'Smallerden', '.', 'The', 'house', 'is', 'white', 'it', 'has', 'stone', 'up', 'the', 'front', 'it', 'is', 'the', 'first', 'from', 'Bridgebrook', 'and', 'the', 'second', 'from', 'Smallerden', '.', 'My', 'Mum', 'is', 'at', 'home', 'She', 'goes', 'to', 'the', 'shop', 'on', 'fridays', 'My', 'Dad', 'goes', 'to', 'work', 'at', 'Smallerden', '.', 'What', 'I', 'do', 'when', 'I', 'get', 'home', 'from', 'school', '.', 'On', 'monday', 'I', 'sometimes', 'go', 'down', 'the', 'farm', 'in', 'the', 'night', 'I', 'watch', 'TV', 'there', 'is', 'BBC', 'and', 'I.T.V', '.', 'I', 'like', 'I.T.V', '.', 'We', 'call', 'Anglia', 'I.T.V', '.', 'We', 'have', 'got', 'Anglia', 'like', 'to', 'watch', 'cowboys', '.', 'On', 'Tuesday', 'I', 'get', 'off', 'the', 'bus', 'and', 'sometimes', 'in', 'the', 'night', 'I', 'go', 'to', 'the', 'Youth', 'club', '.', 'I', 'like', 'to', 'watch', 'T.V', '.', 'there', 'is', 'a', 'lot', 'of', 'things', 'on', 'T.V', '.', 'I', 'watch', 'it', 'each', 'night', '.', '.', 'I', 'think', 'TV', 'is', 'good', 'but', 'people', 'say', 'it', 'gives', 'us', 'square', 'eyes', '.', 'The', 'Murder', 'Car', '.', '1', 'night', 'when', 'it', 'was', 'dark', 'about', '12', "o'clock", 'a', 'man', 'was', 'knocked', 'down', 'by', 'a', 'car', '.', 'The', 'body', 'was', 'found', 'at', '7', "o'clock", 'in', 'the', 'morning', '.', 'The', 'name', 'of', 'the', 'man', 'who', 'was', 'killed', 'was', 'Jack', 'Robbinson', 'he', 'has', 'black', 'hair', 'brown', 'eyes', 'blue', 'Jacket', 'and', 'blue', 'Jeans', '.', 'No', 'one', 'saw', 'the', 'car', '.', 'there', 'had', 'been', 'a', 'lot', 'of', 'people', 'knocked', 'down', 'by', 'a', 'car', 'so', 'they', 'called', 'it', 'the', 'murder', 'car', '.', 'The', 'Police', 'came', 'out', 'to', 'look', 'for', 'the', 'car', '.', 'The', 'other', 'cars', 'were', 'black', 'so', 'one', 'of', 'the', 'other', 'people', 'said', '.', 'The', 'murder', 'man', 'has', 'a', 'black', 'beard', 'The', 'next', 'day', 'one', 'of', 'the', 'policemen', 'were', 'killed', 'the', 'next', 'day', 'they', 'found', 'the', 'car', 'over', 'the', 'Hill', 'there', 'was', 'the', 'man', 'near', 'it', 'he', 'was', 'dead', '.', 'I', 'kissed', 'a', 'girl', 'one', 'night', 'Her', 'eyes', 'were', 'burning', 'blue', 'She', 'said', 'o', 'do', 'you', 'love', 'me', 'Of', 'course', 'of', 'course', 'I', 'do', '.', 'Bell', 'Ringing', '.', 'When', 'you', 'start', 'Bell', 'Ringing', 'you', 'have_to', 'ring', 'a', 'bell', 'before', 'you', 'can', 'do', 'anything', 'else', '.', 'It', 'takes', 'a', 'lot', 'to', 'ring', 'a', 'bell', 'on', 'the', 'rope', 'there', 'is', 'a', 'sally', '.', 'ON', 'the', 'bell', 'there', 'is', 'a', 'wheel', '.', 'the', 'wheel', 'has', 'the', 'rope', 'on', 'it', 'some', 'sallies', 'are', 'green', 'and', 'the', 'others', 'are', 'red', 'white', 'and', 'blue', '.', 'When', 'you', 'can', 'ring', '.', 'You', 'ring', 'like', 'this', '.', 'These', 'are', 'the', 'names', 'of', 'them', 'Plain', 'Hunt', ',', 'plain', 'Bob', ',', 'Grandsire', 'Doubles', '.', 'Grandsire', 'Triples', 'it', 'takes', 'a', 'long', 'time', 'to', 'ring', 'them', '.', 'Me', 'and', 'my', 'dad', 'bike', 'to', 'Melton', '.', 'THE', 'SICK', 'SOW', 'OF', 'THE', 'ARMY', 'C ...

# %%
def accuracy(test):
    # Write your code here    
    check_correct_words = correct(original_test_data)    
    for cword in range(len(check_correct_words)):
#       print(cword)
#       print(corrected_test_data[check_correct_words.index(cword)])
      if check_correct_words[cword] == corrected_test_data[cword]:
        correct_counter.append(check_correct_words[cword])
      else:
        incorrect_counter.append(check_correct_words[cword])
    calc_accuracy = float(len(correct_counter))/len(check_correct_words)
    
#     print(len(check_correct_words))
    print("TRUE ",len(correct_counter))
    print("FALSE ",len(incorrect_counter))
    print(incorrect_counter)
    print(set(correct_counter))
    return calc_accuracy

print(accuracy(test))
# Out:
# ('TRUE ', 894)
# ('FALSE ', 242)
# ['died', 'the', 'the', 'the', 'the', 'go', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'thing', 'the', 'the', 'the', 'the', 'the', 'a', 'the', 'the', 'the', 'the', 'see', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'Here', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'other', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'to', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'go', 'the', 'here', 'the', 'the', 'the', 'here', 'the', 'the', 'the', 'here', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'shore', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'there', 'the', 'the', 'shore', 'as', 'the', 'the', 'came', 'the', 'of', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'and', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'to', 'the', 'the', 'the', 'the', 'to', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'to', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the']
# set(['shop', 'What', 'be', 'being', 'over', 'young', 'four', 'course', 'go', 'milk', 'Dad', 'We', 'mother', 'bell', 'had', ',', 'should', 'better', 'to', 'only', 'other', 'black', 'has', 'might', 'sent', 'take', 'dad', 'do', 'them', 'good', '7', 'get', 'food', 'Car', 'stop', 'Youth', '2', 'made', 'She', 'they', 'not', 'world', 'THE', 'day', 'name', 'going', 'school', 'OK', 'like', 'did', 'OF', 'morning', 'large', 'London', 'she', 'each', 'found', 'went', 'works', 'page', 'poor', 'policemen', 'people', 'doing', 'house', 'Saturday', 'some', 'back', 'dead', 'hair', 'Enfield', 'see', 'been', 'bed', 'Mum', 'home', 'girl', 'out', 'blue', 'leave', 'what', 'said', 'give', 'for', 'away', 'while', 'I', 'laid', 'goes', 'got', 'red', 'told', 'body', 'fight', 'we', 'after', 'cars', 'night', 'vet', 'put', 'Bob', 'strong', 'My', 'by', 'box', 'on', 'about', 'would', 'brown', 'of', 'days', 'meal', 'thing', 'dinner', 'pigs', 'place', 'first', 'feed', 'Then', 'love', 'No', 'straw', 'When', 'one', 'down', 'because', 'done', 'names', 'sow', 'church', 'ring', 'next', 'little', 'from', 'takes', 'her', 'their', 'Tonbury', 'there', 'long', '.', 'start', 'live', 'bike', 'lot', 'then', 'white', 'was', 'gives', 'eyes', 'murder', 'bit', 'way', 'that', 'bus', 'but', 'Jacket', 'warm', 'So', 'line', 'with', 'eat', 'he', 'me', '10', '12', 'look', 'Family', 'this', 'car', 'work', 'up', 'us', 'will', 'near', 'can', 'were', 'Melton', 'my', 'called', 'are', 'and', 'heart', 'full', 'Police', 'On', 'is', 'it', 'pig', 'high', 'say', 'at', 'have', 'in', 'You', 'kissed', 'any', 'if', 'sir', 'nights', 'no', 'TV', 'things', 'make', 'six', 'when', '1', 'anything', 'Bridgebrook', '5', 'Jack', 'Of', 'green', 'you', 'smell', 'A', "'s", 'shall', 'farm', 'who', '3', 'T.V', 'nothing', 'The', 'Murder', 'man', 'a', 'dark', 'off', 'wife', 'i', 'light', 'sometimes', 'It', 'fighting', 'One', 'so', 'clean', 'time', '29', 'the', 'having', 'came', 'If'])
# 0.786971830986

# %% [markdown]
# ## **Task 6 (35 Marks):**
#
# Consider a modification to your algorithm that would improve the accuracy of the algorithm developed in Task 3 and 4
#
# * You may resources beyond those provided here.
# * You must **not use the test data** in this task.
# * Provide a short text describing what you intend to do and why.
# * Full marks for this section may be obtained without an implementation, but an implementation is preferred.
# * Your implementation should not consist of more than 50 lines of code
#
# Please note this task is marked according to: demonstration of knowledge from the lecutures (10), originality and appropriateness of solution (10), completeness of description (10) and technical correctness (5)

# %% [markdown]
# **In the current algorithm: **
#
# We are sending the original test data (words containing correct and misspelled) into a correct function, which will filter out all misspelled word and then run the loop to calculate the distance of misspelled word with nearly correct words in data set.  After getting the list of maybe corrected words we will take out their probability using unigram and replace the misspelled word with the max probability of correct word. If, there is a tie between the distance and probability of two words we are explicitly taking the first correct word in the result array. Once we get the correct sentence, we are comparing the result with the test correct sentences to find out the accuracy of an algorithm. The accuracy of the first algorithm is **78.69%.**
#
# I think, there is some flaw in the first algorithm. To try to improve the accuracy and improve my first algorithm. I found out some other effective algorithms (which are taught in the class) which are:
#
# 1.	**Bigram:**
#
#   -	Many times words repeat themselves in pairs like (good, work), (they, go) etc. If we need to identify such pairs of words which will help us in sentiment analysis. To do this, we will generate such word pairs from the given corpus or sentences preserving their sequences. These pairs are called bigrams.
#
#   -	In python nltk, we have an inbuilt function for same. I.e. nltk.bigrams() and to calculate probability we can use another inbuild function of nltk function ConditionalFreqDist, using this we can find the probability.
#
#   **2.	HMM: **
#
#   -	It is mainly used for the analysis of sequence data and is widely used in many fields like speech recognition, gene prediction, pos tagging, text translation, sequence prediction and time series analysis.
#
#   -	It is the most efficient but it takes start probabilities (as per my understating which is given by the user) so we cannot use this model.
#
#   **3.	POS Tagging: **
#
#   -	Parts of speech (POS) tagging means that distribution grammatical classes i.e. appropriate elements of speech tags to every word in a very natural language sentence.
#
#   -	The process takes a word or a sentence as input, assigns a POS tag to the word or to each word within the sentence, and produces the tagged text as output.
#
#   -	POS tagging can be employed in Text to Speech (TTS) applications, information retrieval, parsing,
# information extraction, linguistic research for corpora and also will be used as an intermediate step for higher level NLP tasks such as parsing, semantic analysis, translation, and many additional, which
# makes POS tagging a necessary function for advanced NLP applications.
#
#   -	POS tagging is useful for syntactical parsing as taggers scale back ambiguity from the parser's input sentence, which makes parsing quicker by creating the computational drawback smaller, and the result less ambiguous. It also resolves some ambiguities that are not addressed by the syntactical parser’s language model.
#
#   **4.	Smoothing Methods:**
#
#   -	In add-one smoothing, we add values in the numerator and denominator so that while calculating the probability of some word we will not get the zero probability even if the word is not available in the given sentence or corpus.
#
# **Modified Algorithm: **
#
# -	After checking through the process of all the above different algorithms/methods I decide to go ahead with the POS Tagging because I believe that it will be helpful in increasing the accuracy as is it tagging each word with nouns, verbs, determinant, cardinal number etc. so it will beneficial for us to ignore the cardinal numbers and pronouns.
#
# -	***For example***, in my first algorithm if a sentence contains a word “THRUSH” it will be converted to “house” as the house will have the maximum probability. But that should not happen, as “THRUSH” is a pronoun and has special meaning in the sentence, while the replaced word house don’t make any meaning in the sentence. Similarly, cardinal number “48” is getting converted into “4” maybe cardinal number has some meaning in the sentence and while converting that we are losing the correctness and meaning of the sentence.
#
# -	In addition to, in first algorithm we are not aware of the thing that the word is converting to which part of speech, but in the modified version we can check that out too.
#
# For testing this and to check the accuracy we have done the pos tagging on test original data set and we are passing it to the unchanged correct function. Once the words gets corrected we are checking if the word has either “CD” or “NNP” tag. If they have we are ignoring them (assuming them as a correct). Than calculating the accuracy accordingly by using the formula i.e. no of correct word prediction/total number of words.
#
# Hence, after using POS tagging we are getting an accuracy of **90.05 %**.

# %% [markdown]
# ## **Task 7 (5 Marks):**
#
# Repeat the evaluation (as in Task 5) of your new algorithm and show that it outperforms the algorithm from Task 3 and 4

# %%
tpd = []
for tr in range(len(test)):  
  x = " ".join(test[tr]["original"])
  tpd = tpd + nk.pos_tag(nk.word_tokenize(x))

# %%
print(tpd)
# Out:
# [('1', 'CD'), ('.', '.'), ('NIGEL', 'NNP'), ('THRUSH', 'NNP'), ('page', 'NN'), ('48', 'CD'), ('I', 'PRP'), ('have', 'VBP'), ('four', 'CD'), ('in', 'IN'), ('my', 'PRP$'), ('Family', 'NNP'), ('Dad', 'NNP'), ('Mum', 'NNP'), ('and', 'CC'), ('siter', 'NN'), ('.', '.'), ('My', 'PRP$'), ('Dad', 'NNP'), ('works', 'VBZ'), ('at', 'IN'), ('Melton', 'NNP'), ('.', '.'), ('My', 'PRP$'), ('siter', 'NN'), ('go', 'VBP'), ('to', 'TO'), ('Tonbury', 'NNP'), ('.', '.'), ('My', 'PRP$'), ('Mum', 'NNP'), ('goes', 'VBZ'), ('out', 'RP'), ('some_times', 'NNS'), ('.', '.'), ('I', 'PRP'), ('go', 'VBP'), ('to', 'TO'), ('Bridgebrook', 'NNP'), ('i', 'NN'), ('go', 'VBP'), ('out', 'RP'), ('some_times', 'RB'), ('on', 'IN'), ('Tuesday', 'NNP'), ('night', 'NN'), ('i', 'NN'), ('go', 'VBP'), ('to', 'TO'), ('Youth', 'NNP'), ('clob', 'NN'), ('.', '.'), ('On', 'IN'), ('thursday', 'JJ'), ('nights', 'NNS'), ('I', 'PRP'), ('go', 'VBP'), ('bell_ringing', 'VBG'), ('on', 'IN'), ('Saturdays', 'NNP'), ('I', 'PRP'), ('go', 'VBP'), ('down', 'RB'), ('to', 'TO'), ('the', 'DT'), ('farm', 'NN'), ('.', '.'), ('on', 'IN'), ('sundays', 'NNS'), ('I', 'PRP'), ('go', 'VBP'), ('to', 'TO'), ('church', 'NN'), ('.', '.'), ('I', 'PRP'), ('go', 'VBP'), ('to', 'TO'), ('bed', 'NN'), ('at', 'IN'), ('10', 'CD'), ('o', 'JJ'), ('clock', 'NN'), ('I', 'PRP'), ('wakh', 'VBP'), ('TV', 'NN'), ('at', 'IN'), ('5', 'CD'), ('o', 'JJ'), ('clock', 'NN'), ('I', 'PRP'), ('live', 'VBP'), ('in', 'IN'), ('a', 'DT'), ('house', 'NN'), ('.', '.'), ('The', 'DT'), ('house', 'NN'), ('is', 'VBZ'), ('in', 'IN'), ('the', 'DT'), ('world', 'NN'), ('.', '.'), ('I', 'PRP'), ('live', 'VBP'), ('at', 'IN'), ('Boar', 'NNP'), ('Parva', 'NNP'), ('it', 'PRP'), ('is', 'VBZ'), ('near', 'IN'), ('Melton', 'NNP'), ('and', 'CC'), ('Bridgebrook', 'NNP'), ('and', 'CC'), ('Smallerden', 'NNP'), ('.', '.'), ('The', 'DT'), ('house', 'NN'), ('is', 'VBZ'), ('white', 'JJ'), ('it', 'PRP'), ('has', 'VBZ'), ('stone', 'VBN'), ('up', 'RP'), ('the', 'DT'), ('frount', 'NN'), ('it', 'PRP'), ('is', 'VBZ'), ('the', 'DT'), ('first', 'JJ'), ('from', 'IN'), ('Bridgebrook', 'NNP'), ('and', 'CC'), ('the', 'DT'), ('sexeon', 'NN'), ('from', 'IN'), ('Smallerden', 'NNP'), ('.', '.'), ('My', 'PRP$'), ('Mum', 'NNP'), ('is', 'VBZ'), ('at', 'IN'), ('home', 'NN'), ('She', 'PRP'), ('goes', 'VBZ'), ('to', 'TO'), ('the', 'DT'), ('shop', 'NN'), ('on', 'IN'), ('fridays', 'NNS'), ('My', 'NNP'), ('Dad', 'NNP'), ('goes', 'VBZ'), ('to', 'TO'), ('work', 'VB'), ('at', 'IN'), ('Smallerden', 'NNP'), ('.', '.'), ('What', 'WP'), ('I', 'PRP'), ('do', 'VBP'), ('when', 'WRB'), ('I', 'PRP'), ('get', 'VBP'), ('home', 'NN'), ('from', 'IN'), ('school', 'NN'), ('.', '.'), ('On', 'IN'), ('monday', 'NN'), ('I', 'PRP'), ('sometimes', 'RB'), ('go', 'VBP'), ('down', 'RP'), ('the', 'DT'), ('farm', 'NN'), ('in', 'IN'), ('the', 'DT'), ('night', 'NN'), ('I', 'PRP'), ('wach', 'VBP'), ('TV', 'NN'), ('there', 'EX'), ('is', 'VBZ'), ('BBC', 'NNP'), ('and', 'CC'), ('I.T.V', 'NNP'), ('.', '.'), ('I', 'PRP'), ('like', 'VBP'), ('I.T.V', 'NNP'), ('.', '.'), ('We', 'PRP'), ('call', 'VBP'), ('Anglia', 'NNP'), ('I.T.V', 'NNP'), ('.', '.'), ('We', 'PRP'), ('have', 'VBP'), ('got', 'VBN'), ('Anglia', 'NNP'), ('like', 'IN'), ('to', 'TO'), ('wach', 'VB'), ('cow_Boys', 'NNS'), ('.', '.'), ('On', 'IN'), ('Tuesday', 'NNP'), ('I', 'PRP'), ('get', 'VBP'), ('off', 'IN'), ('the', 'DT'), ('bus', 'NN'), ('and', 'CC'), ('some_times', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('night', 'NN'), ('I', 'PRP'), ('go', 'VBP'), ('to', 'TO'), ('the', 'DT'), ('Youth', 'NNP'), ('colbe', 'NN'), ('.', '.'), ('I', 'PRP'), ('like', 'VBP'), ('to', 'TO'), ('wach', 'VB'), ('T.V', 'NNP'), ('.', '.'), ('there', 'EX'), ('is', 'VBZ'), ('a', 'DT'), ('lot', 'NN'), ('of', 'IN'), ('things', 'NNS'), ('on', 'IN'), ('T.V', 'NNP'), ('.', '.'), ('I', 'PRP'), ('wach', 'VBP'), ('it', 'PRP'), ('each', 'DT'), ('night', 'NN'), ('.', '.'), ('.', '.'), ('I', 'PRP'), ('thing', 'NN'), ('tv', 'NN'), ('is', 'VBZ'), ('good', 'JJ'), ('but', 'CC'), ('people', 'NNS'), ('say', 'VBP' ...

# %%
cx = [wx for wx, px in tpd]
print(len(cx))
# Out:
# 1136

# %%
correct_counter = []
incorrect_counter = []
def accuracy1(test):
    check_correct_words = correct(cx)
    for cword in range(len(check_correct_words)):      
      if ((tpd[cword][1] == 'CD') | (tpd[cword][1] == 'NNP') | (tpd[cword][0] == corrected_test_data[cword])):
        correct_counter.append(tpd[cword][0])  
      else:
        incorrect_counter.append(tpd[cword][0])
    calc_accuracy = float(len(correct_counter))/len(check_correct_words)
    print("TRUE ",len(correct_counter))
    print("FALSE ",len(incorrect_counter))
    print(incorrect_counter)
    print(correct_counter)
    print(len(check_correct_words))
    return calc_accuracy

# %%
print(accuracy1(test))
# Out:
# ('TRUE ', 1023)
# ('FALSE ', 113)
# ['siter', 'siter', 'go', 'some_times', 'some_times', 'clob', 'bell_ringing', 'wakh', 'frount', 'sexeon', 'wach', 'wach', 'cow_Boys', 'some_times', 'colbe', 'wach', 'wach', 'thing', 'tv', 'squar', 'iyes', 'oclock', 'nock', 'a', 'oclock', 'kild', 'see', 'bean', 'nock', 'cald', 'cam', 'killd', 'the', 'Here', 'iyes', 'haveto', 'be_for', 'any_thing', 'als', 'weel', 'weel', 'sally', 'other', 'rings', 'gass', 'marsks', 'foor', 'wat', 'gass', 'marsks', 'to', 'wat', 'wosh', 'prasp', 'et', 'be_for', 'wiskey', 'soape', 'wiskey', 'cave', 'cave', 'go', 'here', 'here', 'sope', 'wat', 'here', 'cave', 'wiskey', 'sope', 'cave', 'knver', 'thats', 'kild', 'wate', 'injeck', 'mack', 'shore', 'drye', 'falk', 'nock', 'them_souve', 'the', 'worme', 'pouder', 'worme', 'ge', 'there', 'theme', 'geep', 'shore', 'as', 'a_nougth', 'came', 'of', 'fating', 'eate', 'biger', 'fating', 'whe', 'wones', 'and', 'bing', 'waying', 'waid', 'reddy', 'kild', 'to', 'to', 'fro', 'the', 'to', 'though']
# ['1', '.', 'NIGEL', 'THRUSH', 'page', '48', 'I', 'have', 'four', 'in', 'my', 'Family', 'Dad', 'Mum', 'and', '.', 'My', 'Dad', 'works', 'at', 'Melton', '.', 'My', 'to', 'Tonbury', '.', 'My', 'Mum', 'goes', 'out', '.', 'I', 'go', 'to', 'Bridgebrook', 'i', 'go', 'out', 'on', 'Tuesday', 'night', 'i', 'go', 'to', 'Youth', '.', 'On', 'thursday', 'nights', 'I', 'go', 'on', 'Saturdays', 'I', 'go', 'down', 'to', 'the', 'farm', '.', 'on', 'sundays', 'I', 'go', 'to', 'church', '.', 'I', 'go', 'to', 'bed', 'at', '10', 'o', 'clock', 'I', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house', '.', 'The', 'house', 'is', 'in', 'the', 'world', '.', 'I', 'live', 'at', 'Boar', 'Parva', 'it', 'is', 'near', 'Melton', 'and', 'Bridgebrook', 'and', 'Smallerden', '.', 'The', 'house', 'is', 'white', 'it', 'has', 'stone', 'up', 'the', 'it', 'is', 'the', 'first', 'from', 'Bridgebrook', 'and', 'the', 'from', 'Smallerden', '.', 'My', 'Mum', 'is', 'at', 'home', 'She', 'goes', 'to', 'the', 'shop', 'on', 'fridays', 'My', 'Dad', 'goes', 'to', 'work', 'at', 'Smallerden', '.', 'What', 'I', 'do', 'when', 'I', 'get', 'home', 'from', 'school', '.', 'On', 'monday', 'I', 'sometimes', 'go', 'down', 'the', 'farm', 'in', 'the', 'night', 'I', 'TV', 'there', 'is', 'BBC', 'and', 'I.T.V', '.', 'I', 'like', 'I.T.V', '.', 'We', 'call', 'Anglia', 'I.T.V', '.', 'We', 'have', 'got', 'Anglia', 'like', 'to', '.', 'On', 'Tuesday', 'I', 'get', 'off', 'the', 'bus', 'and', 'in', 'the', 'night', 'I', 'go', 'to', 'the', 'Youth', '.', 'I', 'like', 'to', 'T.V', '.', 'there', 'is', 'a', 'lot', 'of', 'things', 'on', 'T.V', '.', 'I', 'it', 'each', 'night', '.', '.', 'I', 'is', 'good', 'but', 'people', 'say', 'it', 'gives', 'us', '.', 'The', 'Murder', 'Car', '.', '1', 'night', 'when', 'it', 'was', 'dark', 'about', '12', 'a', 'man', 'was', 'down', 'by', 'a', 'car', '.', 'The', 'body', 'was', 'found', '7', 'in', 'the', 'morning', '.', 'The', 'name', 'of', 'the', 'man', 'who', 'was', 'was', 'Jack', 'Robbinson', 'he', 'has', 'black', 'hair', 'brown', 'eyes', 'blue', 'Jacket', 'and', 'blue', 'Jeans', '.', 'No', 'one', 'the', 'car', '.', 'there', 'had', 'a', 'lot', 'of', 'people', 'down', 'by', 'a', 'car', 'so', 'they', 'it', 'the', 'murder', 'car', '.', 'The', 'Police', 'out', 'to', 'look', 'for', 'the', 'car', '.', 'The', 'other', 'cars', 'were', 'black', 'so', 'one', 'of', 'the', 'other', 'people', 'said', '.', 'The', 'murder', 'man', 'has', 'a', 'black', 'beard', 'The', 'next', 'day', 'one', 'of', 'the', 'policemen', 'were', 'the', 'next', 'day', 'they', 'found', 'the', 'car', 'over', 'the', 'Hill', 'was', 'the', 'man', 'near', 'it', 'he', 'was', 'dead', '.', 'I', 'kissed', 'a', 'girl', 'one', 'night', 'were', 'burning', 'blue', 'She', 'said', 'o', 'do', 'you', 'love', 'me', 'Of', 'course', 'of', 'course', 'I', 'do', '.', 'Bell', 'Ringing', '.', 'When', 'you', 'start', 'Bell', 'Ringing', 'you', 'ring', 'a', 'bell', 'you', 'can', 'do', '.', 'It', 'takes', 'a', 'lot', 'to', 'ring', 'a', 'bell', 'on', 'the', 'rope', 'there', 'is', 'a', 'sally', '.', 'ON', 'the', 'bell', 'there', 'is', 'a', '.', 'the', 'has', 'the', 'rope', 'on', 'it', 'some', 'are', 'green', 'and', 'the', 'are', 'red', 'white', 'and', 'blue', '.', 'When', 'you', 'can', 'ring', '.', 'You', 'like', 'this', '.', 'These', 'are', 'the', 'names', 'of', 'them', 'Plain', 'Hunt', ',', 'plain', 'Bob', ',', 'Grandsire', 'Doubles', '.', 'Grandsire', 'Triples', 'it', 'takes', 'a', 'long', 'time', 'to', 'ring', 'them', '.', 'Me', 'and', 'my', 'dad', 'bike', 'to', 'Melton', '.', 'THE', 'SICK', 'SOW', 'OF', 'THE', 'ARMY', 'COURT', 'One', 'day', 'Sergent', 'S', '.', 'M', '.', 'Bullimore', 'told', 'Hut', '29', 'to', 'clean', 'Cynthia', "'s", 'pig', 'sty', 'out', '.', 'When', 'Hut', '29', 'got', 'there', 'they', 'had', 'to', 'go', 'and', 'get', 'some', 'because', 'the', 'smell', 'was', 'to', 'strong', 'When', 'S', 'M', 'Bullimore', 'came', 'to', 'the', 'pig', 'sty', 'the', 'pig', 'was', 'laid', 'out', 'on', 'the', 'when', 'they', 'came', 'b ...
# 1136
# 0.900528169014
